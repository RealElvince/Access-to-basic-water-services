# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Transform columns using numeric functions

# %% [markdown]
# In this notebook, we demonstrate how to use numeric functions to transform columns in a table in SQL.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# By the end of this train, you should:
# - Understand how to use `SQRT`, `LOG`, and `ROUND` functions to transform columns in a table in SQL.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Continuing with the numerical analysis of our  Access_to_Basic_Services table, we are trying to get an understanding of the scope of our dataset, more specifically, the numerical columns. We can apply the same queries in MySQL Workbench and in this notebook if we connect to our MySQL server.
# Since we have a MySQL database, we can connect to it using mysql and pymysql.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
import os
from dotenv import load_dotenv
load_dotenv()

DB_NAME = os.getenv("DB_NAME")
DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT")
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")


conn = f"mysql+pymysql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
# %sql $conn
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line, and then the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ## Exercise
#
# We want to determine the following:
#
# 1. What is the GDP per year for each country?
# 2. What are the rounded-off values of the `Est_gdp_in_billions` column?
# 3. What is the logarithm of GDP for each country over the time period?
# 4. What is the square root of GDP for each country over the time period?

# %% [markdown]
# ### 1. What is the GDP per year for each country?
#
# Calculate the GDP per year for each country using the `Country_name`, `Time_period`, and `Est_gdp_in_billions` columns.

# %%
# %%sql
# SELECT
#     Country_name,
#     Time_period,
#     Est_gdp_in_billions
# FROM
#     united_nations.access_to_basic_services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Kazakhstan', 2015, Decimal('184.39')),
#  ('Kazakhstan', 2016, Decimal('137.28')),
#  ('Kazakhstan', 2017, Decimal('166.81')),
#  ('Kazakhstan', 2018, Decimal('179.34')),
#  ('Kazakhstan', 2019, Decimal('181.67')),
#  ('Kazakhstan', 2020, Decimal('171.08')),
#  ('Kyrgyzstan', 2015, None),
#  ('Kyrgyzstan', 2016, None),
#  ('Kyrgyzstan', 2017, None),
#  ('Kyrgyzstan', 2018, None),
#  ('Kyrgyzstan', 2019, None),
#  ('Kyrgyzstan', 2020, None),
#  ('Tajikistan', 2015, Decimal('8.27')),
#  ('Tajikistan', 2016, Decimal('6.99')),
#  ('Tajikistan', 2017, Decimal('7.54')),
#  ('Tajikistan', 2018, Decimal('7.77')),
#  ('Tajikistan', 2019, Decimal('8.30')),
#  ('Tajikistan', 2020, Decimal('8.13')),
#  ('Turkmenistan', 2015, Decimal('35.80')),
#  ('Turkmenistan', 2016, Decimal('36.17')),
#  ('Turkmenistan', 2017, Decimal('37.93')),
#  ('Turkmenistan', 2018, Decimal('40.77')),
#  ('Turkmenistan', 2019, Decimal('45.23')),
#  ('Turkmenistan', 2020, None),
#  ('Uzbekistan', 2015, Decimal('86.20')),
#  ('Uzbekistan', 2016, Decimal('86.14')),
#  ('Uzbekistan', 2017, Decimal('62.08')),
#  ('Uzbekistan', 2018, Decimal('52.63')),
#  ('Uzbekistan', 2019, Decimal('59.91')),
#  ('Uzbekistan', 2020, Decimal('59.89')),
#  ('Afghanistan', 2015, Decimal('20.00')),
#  ('Afghanistan', 2016, Decimal('18.02')),
#  ('Afghanistan', 2017, Decimal('18.90')),
#  ('Afghanistan', 2018, Decimal('18.42')),
#  ('Afghanistan', 2019, Decimal('18.90')),
#  ('Afghanistan', 2020, Decimal('20.14')),
#  ('Bangladesh', 2015, Decimal('195.08')),
#  ('Bangladesh', 2016, Decimal('265.24')),
#  ('Bangladesh', 2017, Decimal('293.75')),
#  ('Bangladesh', 2018, Decimal('321.38')),
#  ('Bangladesh', 2019, Decimal('351.24')),
#  ('Bangladesh', 2020, Decimal('373.90')),
#  ('Bhutan', 2015, Decimal('2.00')),
#  ('Bhutan', 2016, Decimal('2.16')),
#  ('Bhutan', 2017, Decimal('2.45')),
#  ('Bhutan', 2018, Decimal('2.45')),
#  ('Bhutan', 2019, Decimal('2.54')),
#  ('Bhutan', 2020, Decimal('2.33')),
#  ('India', 2015, Decimal('2103.59')),
#  ('India', 2016, Decimal('2294.80')),
#  ('India', 2017, Decimal('2651.47')),
#  ('India', 2018, Decimal('2702.93')),
#  ('India', 2019, Decimal('2831.55')),
#  ('India', 2020, Decimal('2667.69')),
#  ('Iran (Islamic Republic of)', 2015, None),
#  ('Iran (Islamic Republic of)', 2016, None),
#  ('Iran (Islamic Republic of)', 2017, None),
#  ('Iran (Islamic Republic of)', 2018, None),
#  ('Iran (Islamic Republic of)', 2019, None),
#  ('Iran (Islamic Republic of)', 2020, None),
#  ('Maldives', 2015, Decimal('4.11')),
#  ('Maldives', 2016, Decimal('4.38')),
#  ('Maldives', 2017, Decimal('4.75')),
#  ('Maldives', 2018, Decimal('5.30')),
#  ('Maldives', 2019, Decimal('5.61')),
#  ('Maldives', 2020, Decimal('3.75')),
#  ('Nepal', 2015, Decimal('24.36')),
#  ('Nepal', 2016, Decimal('24.52')),
#  ('Nepal', 2017, Decimal('28.97')),
#  ('Nepal', 2018, Decimal('33.11')),
#  ('Nepal', 2019, Decimal('34.19')),
#  ('Nepal', 2020, Decimal('33.43')),
#  ('Pakistan', 2015, Decimal('270.56')),
#  ('Pakistan', 2016, Decimal('313.63')),
#  ('Pakistan', 2017, Decimal('339.21')),
#  ('Pakistan', 2018, Decimal('356.13')),
#  ('Pakistan', 2019, Decimal('320.91')),
#  ('Pakistan', 2020, Decimal('300.43')),
#  ('Sri Lanka', 2015, Decimal('85.14')),
#  ('Sri Lanka', 2016, Decimal('88.01')),
#  ('Sri Lanka', 2017, Decimal('94.38')),
#  ('Sri Lanka', 2018, Decimal('94.49')),
#  ('Sri Lanka', 2019, Decimal('89.01')),
#  ('Sri Lanka', 2020, Decimal('85.35')),
#  ('China', 2015, Decimal('11061.55')),
#  ('China', 2016, Decimal('11233.28')),
#  ('China', 2017, Decimal('12310.41')),
#  ('China', 2018, Decimal('13894.82')),
#  ('China', 2019, Decimal('14279.94')),
#  ('China', 2020, Decimal('14687.67')),
#  ("Democratic People's Republic of Korea", 2015, None),
#  ("Democratic People's Republic of Korea", 2016, None),
#  ("Democratic People's Republic of Korea", 2017, None),
#  ("Democratic People's Republic of Korea", 2018, None),
#  ("Democratic People's Republic of Korea", 2019, None),
#  ("Democratic People's Republic of Korea", 2020, None),
#  ('Japan', 2015, Decimal('4444.93')),
#  ('Japan', 2016, Decimal('5003.68')),
#  ('Japan', 2017, Decimal('4930.84')),
#  ('Japan', 2018, Decimal('5037.84')),
#  ('Japan', 2019, Decimal('5123.32')),
#  ('Japan', 2020, Decimal('5040.11')),
#  ('Mongolia', 2015, Decimal('11.62')),
#  ('Mongolia', 2016, Decimal('11.18')),
#  ('Mongolia', 2017, Decimal('11.48')),
#  ('Mongolia', 2018, Decimal('13.18')),
#  ('Mongolia', 2019, Decimal('14.21')),
#  ('Mongolia', 2020, Decimal('13.31')),
#  ('Republic of Korea', 2015, None),
#  ('Republic of Korea', 2016, None),
#  ('Republic of Korea', 2017, None),
#  ('Republic of Korea', 2018, None),
#  ('Republic of Korea', 2019, None),
#  ('Republic of Korea', 2020, None),
#  ('Brunei Darussalam', 2015, Decimal('12.93')),
#  ('Brunei Darussalam', 2016, Decimal('11.40')),
#  ('Brunei Darussalam', 2017, Decimal('12.13')),
#  ('Brunei Darussalam', 2018, Decimal('13.57')),
#  ('Brunei Darussalam', 2019, Decimal('13.47')),
#  ('Brunei Darussalam', 2020, Decimal('12.01')),
#  ('Cambodia', 2015, Decimal('18.05')),
#  ('Cambodia', 2016, Decimal('20.02')),
#  ('Cambodia', 2017, Decimal('22.18')),
#  ('Cambodia', 2018, Decimal('24.57')),
#  ('Cambodia', 2019, Decimal('27.09')),
#  ('Cambodia', 2020, Decimal('25.87')),
#  ('Indonesia', 2015, Decimal('860.85')),
#  ('Indonesia', 2016, Decimal('931.88')),
#  ('Indonesia', 2017, Decimal('1015.62')),
#  ('Indonesia', 2018, Decimal('1042.27')),
#  ('Indonesia', 2019, Decimal('1119.10')),
#  ('Indonesia', 2020, Decimal('1058.69')),
#  ("Lao People's Democratic Republic", 2015, None),
#  ("Lao People's Democratic Republic", 2016, None),
#  ("Lao People's Democratic Republic", 2017, None),
#  ("Lao People's Democratic Republic", 2018, None),
#  ("Lao People's Democratic Republic", 2019, None),
#  ("Lao People's Democratic Republic", 2020, None),
#  ('Malaysia', 2015, Decimal('301.35')),
#  ('Malaysia', 2016, Decimal('301.26')),
#  ('Malaysia', 2017, Decimal('319.11')),
#  ('Malaysia', 2018, Decimal('358.79')),
#  ('Malaysia', 2019, Decimal('365.18')),
#  ('Malaysia', 2020, Decimal('337.34')),
#  ('Myanmar', 2015, Decimal('63.05')),
#  ('Myanmar', 2016, Decimal('60.29')),
#  ('Myanmar', 2017, Decimal('61.45')),
#  ('Myanmar', 2018, Decimal('67.14')),
#  ('Myanmar', 2019, Decimal('68.70')),
#  ('Myanmar', 2020, Decimal('78.93')),
#  ('Philippines', 2015, Decimal('306.45')),
#  ('Philippines', 2016, Decimal('318.63')),
#  ('Philippines', 2017, Decimal('328.48')),
#  ('Philippines', 2018, Decimal('346.84')),
#  ('Philippines', 2019, Decimal('376.82')),
#  ('Philippines', 2020, Decimal('361.75')),
#  ('Singapore', 2015, Decimal('308.00')),
#  ('Singapore', 2016, Decimal('318.83')),
#  ('Singapore', 2017, Decimal('343.19')),
#  ('Singapore', 2018, Decimal('377.00')),
#  ('Singapore', 2019, Decimal('375.47')),
#  ('Singapore', 2020, Decimal('345.30')),
#  ('Thailand', 2015, Decimal('401.30')),
#  ('Thailand', 2016, Decimal('413.37')),
#  ('Thailand', 2017, Decimal('456.36')),
#  ('Thailand', 2018, Decimal('506.75')),
#  ('Thailand', 2019, Decimal('544.08')),
#  ('Thailand', 2020, Decimal('499.68')),
#  ('Timor-Leste', 2015, Decimal('1.59')),
#  ('Timor-Leste', 2016, Decimal('1.65')),
#  ('Timor-Leste', 2017, Decimal('1.60')),
#  ('Timor-Leste', 2018, Decimal('1.56')),
#  ('Timor-Leste', 2019, Decimal('2.03')),
#  ('Timor-Leste', 2020, Decimal('2.16')),
#  ('Viet Nam', 2015, None),
#  ('Viet Nam', 2016, None),
#  ('Viet Nam', 2017, None),
#  ('Viet Nam', 2018, None),
#  ('Viet Nam', 2019, None),
#  ('Viet Nam', 2020, None),
#  ('Bermuda', 2015, Decimal('6.65')),
#  ('Bermuda', 2016, Decimal('6.90')),
#  ('Bermuda', 2017, Decimal('7.14')),
#  ('Bermuda', 2018, Decimal('7.23')),
#  ('Bermuda', 2019, Decimal('7.42')),
#  ('Bermuda', 2020, Decimal('6.89')),
#  ('Canada', 2015, Decimal('1556.51')),
#  ('Canada', 2016, Decimal('1527.99')),
#  ('Canada', 2017, Decimal('1649.27')),
#  ('Canada', 2018, Decimal('1725.33')),
#  ('Canada', 2019, Decimal('1742.02')),
#  ('Canada', 2020, Decimal('1645.42')),
#  ('Greenland', 2015, Decimal('2.50')),
#  ('Greenland', 2016, Decimal('2.71')),
#  ('Greenland', 2017, Decimal('2.85')),
#  ('Greenland', 2018, Decimal('3.06')),
#  ('Greenland', 2019, Decimal('2.99')),
#  ('Greenland', 2020, Decimal('3.08')),
#  ('Saint Pierre and Miquelon', 2015, None),
#  ('Saint Pierre and Miquelon', 2016, None),
#  ('Saint Pierre and Miquelon', 2017, None),
#  ('Saint Pierre and Miquelon', 2018, None),
#  ('Saint Pierre and Miquelon', 2019, None),
#  ('Saint Pierre and Miquelon', 2020, None),
#  ('United States of America', 2015, None),
#  ('United States of America', 2016, None),
#  ('United States of America', 2017, None),
#  ('United States of America', 2018, None),
#  ('United States of America', 2019, None),
#  ('United States of America', 2020, None),
#  ('Anguilla', 2015, None),
#  ('Anguilla', 2016, None),
#  ('Anguilla', 2017, None),
#  ('Antigua and Barbuda', 2015, Decimal('1.34')),
#  ('Antigua and Barbuda', 2016, Decimal('1.44')),
#  ('Antigua and Barbuda', 2017, Decimal('1.47')),
#  ('Aruba', 2015, Decimal('2.96')),
#  ('Aruba', 2016, Decimal('2.98')),
#  ('Bahamas', 2015, None),
#  ('Bahamas', 2016, None),
#  ('Bahamas', 2017, None),
#  ('Bahamas', 2018, None),
#  ('Bahamas', 2019, None),
#  ('Barbados', 2015, Decimal('4.72')),
#  ('Barbados', 2016, Decimal('4.83')),
#  ('Barbados', 2017, Decimal('4.98')),
#  ('Barbados', 2018, Decimal('5.10')),
#  ('Barbados', 2019, Decimal('5.32')),
#  ('Barbados', 2020, Decimal('4.67')),
#  ('British Virgin Islands', 2015, None),
#  ('British Virgin Islands', 2016, None),
#  ('British Virgin Islands', 2017, None),
#  ('British Virgin Islands', 2018, None),
#  ('British Virgin Islands', 2019, None),
#  ('British Virgin Islands', 2020, None),
#  ('Cayman Islands', 2015, Decimal('4.71')),
#  ('Cayman Islands', 2016, Decimal('4.91')),
#  ('Cuba', 2015, Decimal('87.13')),
#  ('Cuba', 2016, Decimal('91.37')),
#  ('Cuba', 2017, Decimal('96.85')),
#  ('Cuba', 2018, Decimal('100.05')),
#  ('Cuba', 2019, Decimal('103.43')),
#  ('Cuba', 2020, Decimal('107.35')),
#  ('Curaçao', 2015, None),
#  ('Curaçao', 2016, None),
#  ('Curaçao', 2017, None),
#  ('Dominica', 2015, Decimal('0.54')),
#  ('Dominica', 2016, Decimal('0.58')),
#  ('Dominica', 2017, Decimal('0.52')),
#  ('Dominican Republic', 2015, Decimal('71.16')),
#  ('Dominican Republic', 2016, Decimal('75.70')),
#  ('Dominican Republic', 2017, Decimal('80.00')),
#  ('Dominican Republic', 2018, Decimal('85.56')),
#  ('Dominican Republic', 2019, Decimal('88.94')),
#  ('Dominican Republic', 2020, Decimal('78.84')),
#  ('Grenada', 2015, Decimal('1.00')),
#  ('Grenada', 2016, Decimal('1.06')),
#  ('Grenada', 2017, Decimal('1.13')),
#  ('Guadeloupe', 2015, None),
#  ('Guadeloupe', 2016, None),
#  ('Guadeloupe', 2017, None),
#  ('Guadeloupe', 2018, None),
#  ('Guadeloupe', 2019, None),
#  ('Guadeloupe', 2020, None),
#  ('Haiti', 2015, Decimal('14.83')),
#  ('Haiti', 2016, Decimal('13.99')),
#  ('Haiti', 2017, Decimal('15.04')),
#  ('Haiti', 2018, Decimal('16.46')),
#  ('Haiti', 2019, Decimal('14.79')),
#  ('Haiti', 2020, Decimal('14.51')),
#  ('Jamaica', 2015, Decimal('14.19')),
#  ('Jamaica', 2016, Decimal('14.08')),
#  ('Jamaica', 2017, Decimal('14.81')),
#  ('Jamaica', 2018, Decimal('15.73')),
#  ('Jamaica', 2019, Decimal('15.83')),
#  ('Jamaica', 2020, Decimal('13.81')),
#  ('Martinique', 2015, None),
#  ('Martinique', 2016, None),
#  ('Martinique', 2017, None),
#  ('Martinique', 2018, None),
#  ('Martinique', 2019, None),
#  ('Martinique', 2020, None),
#  ('Montserrat', 2015, None),
#  ('Montserrat', 2016, None),
#  ('Montserrat', 2017, None),
#  ('Montserrat', 2018, None),
#  ('Montserrat', 2019, None),
#  ('Montserrat', 2020, None),
#  ('Puerto Rico', 2015, Decimal('103.38')),
#  ('Puerto Rico', 2016, Decimal('104.34')),
#  ('Puerto Rico', 2017, Decimal('103.45')),
#  ('Puerto Rico', 2018, Decimal('100.96')),
#  ('Puerto Rico', 2019, Decimal('105.13')),
#  ('Puerto Rico', 2020, Decimal('103.02')),
#  ('Saint Barthélemy', 2015, None),
#  ('Saint Barthélemy', 2016, None),
#  ('Saint Barthélemy', 2017, None),
#  ('Saint Barthélemy', 2018, None),
#  ('Saint Barthélemy', 2019, None),
#  ('Saint Barthélemy', 2020, None),
#  ('Saint Kitts and Nevis', 2015, None),
#  ('Saint Kitts and Nevis', 2016, None),
#  ('Saint Kitts and Nevis', 2017, None),
#  ('Saint Lucia', 2015, None),
#  ('Saint Lucia', 2016, None),
#  ('Saint Lucia', 2017, None),
#  ('Saint Lucia', 2018, None),
#  ('Saint Lucia', 2019, None),
#  ('Saint Lucia', 2020, None),
#  ('Saint Martin (French Part)', 2015, None),
#  ('Saint Martin (French Part)', 2016, None),
#  ('Saint Martin (French Part)', 2017, None),
#  ('Saint Martin (French Part)', 2018, None),
#  ('Saint Martin (French Part)', 2019, None),
#  ('Saint Martin (French Part)', 2020, None),
#  ('Saint Vincent and the Grenadines', 2015, None),
#  ('Saint Vincent and the Grenadines', 2016, None),
#  ('Saint Vincent and the Grenadines', 2017, None),
#  ('Saint Vincent and the Grenadines', 2018, None),
#  ('Sint Maarten (Dutch part)', 2015, Decimal('1.25')),
#  ('Sint Maarten (Dutch part)', 2016, Decimal('1.26')),
#  ('Sint Maarten (Dutch part)', 2017, Decimal('1.19')),
#  ('Trinidad and Tobago', 2015, Decimal('26.85')),
#  ('Trinidad and Tobago', 2016, Decimal('23.50')),
#  ('Trinidad and Tobago', 2017, Decimal('23.80')),
#  ('Trinidad and Tobago', 2018, Decimal('24.32')),
#  ('Trinidad and Tobago', 2019, Decimal('23.85')),
#  ('Trinidad and Tobago', 2020, Decimal('21.06')),
#  ('Turks and Caicos Islands', 2015, Decimal('0.94')),
#  ('Turks and Caicos Islands', 2016, Decimal('1.03')),
#  ('Turks and Caicos Islands', 2017, Decimal('1.02')),
#  ('Turks and Caicos Islands', 2018, Decimal('1.11')),
#  ('United States Virgin Islands', 2015, None),
#  ('United States Virgin Islands', 2016, None),
#  ('United States Virgin Islands', 2017, None),
#  ('United States Virgin Islands', 2018, None),
#  ('United States Virgin Islands', 2019, None),
#  ('United States Virgin Islands', 2020, None),
#  ('Belize', 2015, Decimal('2.21')),
#  ('Belize', 2016, Decimal('2.26')),
#  ('Belize', 2017, Decimal('2.29')),
#  ('Belize', 2018, Decimal('2.31')),
#  ('Belize', 2019, Decimal('2.42')),
#  ('Belize', 2020, Decimal('2.08')),
#  ('Costa Rica', 2015, Decimal('56.44')),
#  ('Costa Rica', 2016, Decimal('58.85')),
#  ('Costa Rica', 2017, Decimal('60.52')),
#  ('Costa Rica', 2018, Decimal('62.42')),
#  ('Costa Rica', 2019, Decimal('64.42')),
#  ('Costa Rica', 2020, Decimal('62.16')),
#  ('El Salvador', 2015, Decimal('23.44')),
#  ('El Salvador', 2016, Decimal('24.19')),
#  ('El Salvador', 2017, Decimal('24.98')),
#  ('El Salvador', 2018, Decimal('26.02')),
#  ('El Salvador', 2019, Decimal('26.88')),
#  ('El Salvador', 2020, Decimal('24.56')),
#  ('Guatemala', 2015, Decimal('62.19')),
#  ('Guatemala', 2016, Decimal('66.05')),
#  ('Guatemala', 2017, Decimal('71.65')),
#  ('Guatemala', 2018, Decimal('73.33')),
#  ('Guatemala', 2019, Decimal('77.17')),
#  ('Guatemala', 2020, Decimal('77.63')),
#  ('Honduras', 2015, Decimal('20.98')),
#  ('Honduras', 2016, Decimal('21.72')),
#  ('Honduras', 2017, Decimal('23.14')),
#  ('Honduras', 2018, Decimal('24.07')),
#  ('Honduras', 2019, Decimal('25.09')),
#  ('Honduras', 2020, Decimal('23.83')),
#  ('Mexico', 2015, Decimal('1171.87')),
#  ('Mexico', 2016, Decimal('1078.49')),
#  ('Mexico', 2017, Decimal('1158.91')),
#  ('Mexico', 2018, Decimal('1222.41')),
#  ('Mexico', 2019, Decimal('1269.01')),
#  ('Mexico', 2020, Decimal('1090.52')),
#  ('Nicaragua', 2015, Decimal('12.76')),
#  ('Nicaragua', 2016, Decimal('13.29')),
#  ('Nicaragua', 2017, Decimal('13.79')),
#  ('Nicaragua', 2018, Decimal('13.03')),
#  ('Nicaragua', 2019, Decimal('12.60')),
#  ('Nicaragua', 2020, Decimal('12.59')),
#  ('Panama', 2015, Decimal('54.09')),
#  ('Panama', 2016, Decimal('57.91')),
#  ('Panama', 2017, Decimal('62.20')),
#  ('Panama', 2018, Decimal('64.93')),
#  ('Panama', 2019, Decimal('66.98')),
#  ('Panama', 2020, Decimal('53.98')),
#  ('Argentina', 2015, Decimal('594.75')),
#  ('Argentina', 2016, Decimal('557.53')),
#  ('Argentina', 2017, Decimal('643.63')),
#  ('Argentina', 2018, Decimal('524.82')),
#  ('Argentina', 2019, Decimal('447.75')),
#  ('Argentina', 2020, Decimal('385.54')),
#  ('Bolivia (Plurinational State of)', 2015, None),
#  ('Bolivia (Plurinational State of)', 2016, None),
#  ('Bolivia (Plurinational State of)', 2017, None),
#  ('Bolivia (Plurinational State of)', 2018, None),
#  ('Bolivia (Plurinational State of)', 2019, None),
#  ('Bolivia (Plurinational State of)', 2020, None),
#  ('Brazil', 2015, Decimal('1802.21')),
#  ('Brazil', 2016, Decimal('1795.70')),
#  ('Brazil', 2017, Decimal('2063.51')),
#  ('Brazil', 2018, Decimal('1916.95')),
#  ('Brazil', 2019, Decimal('1873.27')),
#  ('Brazil', 2020, Decimal('1448.56')),
#  ('Chile', 2015, Decimal('242.50')),
#  ('Chile', 2016, Decimal('249.30')),
#  ('Chile', 2017, Decimal('276.36')),
#  ('Chile', 2018, Decimal('295.40')),
#  ('Chile', 2019, Decimal('278.58')),
#  ('Chile', 2020, Decimal('252.73')),
#  ('Colombia', 2015, Decimal('293.48')),
#  ('Colombia', 2016, Decimal('282.83')),
#  ('Colombia', 2017, Decimal('311.88')),
#  ('Colombia', 2018, Decimal('334.20')),
#  ('Colombia', 2019, Decimal('323.11')),
#  ('Colombia', 2020, Decimal('270.30')),
#  ('Ecuador', 2015, Decimal('99.29')),
#  ('Ecuador', 2016, Decimal('99.94')),
#  ('Ecuador', 2017, Decimal('104.30')),
#  ('Ecuador', 2018, Decimal('107.56')),
#  ('Ecuador', 2019, Decimal('108.11')),
#  ('Ecuador', 2020, Decimal('99.29')),
#  ('Falkland Islands (Malvinas)', 2015, None),
#  ('Falkland Islands (Malvinas)', 2016, None),
#  ('Falkland Islands (Malvinas)', 2017, None),
#  ('Falkland Islands (Malvinas)', 2018, None),
#  ('Falkland Islands (Malvinas)', 2019, None),
#  ('Falkland Islands (Malvinas)', 2020, None),
#  ('French Guiana', 2015, None),
#  ('French Guiana', 2016, None),
#  ('French Guiana', 2017, None),
#  ('French Guiana', 2018, None),
#  ('French Guiana', 2019, None),
#  ('French Guiana', 2020, None),
#  ('Guyana', 2015, Decimal('4.28')),
#  ('Guyana', 2016, Decimal('4.48')),
#  ('Guyana', 2017, Decimal('4.75')),
#  ('Guyana', 2018, Decimal('4.79')),
#  ('Guyana', 2019, Decimal('5.17')),
#  ('Guyana', 2020, Decimal('5.47')),
#  ('Paraguay', 2015, Decimal('36.21')),
#  ('Paraguay', 2016, Decimal('36.09')),
#  ('Paraguay', 2017, Decimal('39.00')),
#  ('Paraguay', 2018, Decimal('40.23')),
#  ('Paraguay', 2019, Decimal('37.93')),
#  ('Paraguay', 2020, Decimal('35.43')),
#  ('Peru', 2015, Decimal('189.81')),
#  ('Peru', 2016, Decimal('191.90')),
#  ('Peru', 2017, Decimal('211.01')),
#  ('Peru', 2018, Decimal('222.60')),
#  ('Peru', 2019, Decimal('228.32')),
#  ('Peru', 2020, Decimal('201.71')),
#  ('Suriname', 2015, Decimal('5.13')),
#  ('Suriname', 2016, Decimal('3.32')),
#  ('Suriname', 2017, Decimal('3.59')),
#  ('Suriname', 2018, Decimal('4.00')),
#  ('Suriname', 2019, Decimal('4.02')),
#  ('Suriname', 2020, Decimal('2.91')),
#  ('Uruguay', 2015, Decimal('53.27')),
#  ('Uruguay', 2016, Decimal('57.24')),
#  ('Uruguay', 2017, Decimal('64.23')),
#  ('Uruguay', 2018, Decimal('64.52')),
#  ('Uruguay', 2019, Decimal('61.23')),
#  ('Uruguay', 2020, Decimal('53.56')),
#  ('Venezuela (Bolivarian Republic of)', 2015, None),
#  ('Venezuela (Bolivarian Republic of)', 2016, None),
#  ('Venezuela (Bolivarian Republic of)', 2017, None),
#  ('Venezuela (Bolivarian Republic of)', 2018, None),
#  ('Venezuela (Bolivarian Republic of)', 2019, None),
#  ('Venezuela (Bolivarian Republic of)', 2020, None),
#  ('Algeria', 2015, Decimal('165.98')),
#  ('Algeria', 2016, Decimal('160.03')),
#  ('Algeria', 2017, Decimal('170.10')),
#  ('Algeria', 2018, Decimal('174.91')),
#  ('Algeria', 2019, Decimal('171.77')),
#  ('Algeria', 2020, Decimal('145.01')),
#  ('Egypt', 2015, None),
#  ('Egypt', 2016, None),
#  ('Egypt', 2017, None),
#  ('Egypt', 2018, None),
#  ('Egypt', 2019, None),
#  ('Egypt', 2020, None),
#  ('Libya', 2015, Decimal('48.72')),
#  ('Libya', 2016, Decimal('49.91')),
#  ('Libya', 2017, Decimal('67.16')),
#  ('Libya', 2018, Decimal('76.68')),
#  ('Libya', 2019, Decimal('69.25')),
#  ('Libya', 2020, Decimal('50.36')),
#  ('Morocco', 2015, Decimal('110.41')),
#  ('Morocco', 2016, Decimal('111.57')),
#  ('Morocco', 2017, Decimal('118.54')),
#  ('Morocco', 2018, Decimal('127.34')),
#  ('Morocco', 2019, Decimal('128.92')),
#  ('Morocco', 2020, Decimal('121.35')),
#  ('Sudan', 2015, Decimal('84.99')),
#  ('Sudan', 2016, Decimal('102.94')),
#  ('Sudan', 2017, Decimal('129.72')),
#  ('Sudan', 2018, Decimal('32.33')),
#  ('Sudan', 2019, Decimal('32.34')),
#  ('Sudan', 2020, Decimal('27.03')),
#  ('Tunisia', 2015, Decimal('45.78')),
#  ('Tunisia', 2016, Decimal('44.36')),
#  ('Tunisia', 2017, Decimal('42.16')),
#  ('Tunisia', 2018, Decimal('42.69')),
#  ('Tunisia', 2019, Decimal('41.91')),
#  ('Tunisia', 2020, Decimal('42.54')),
#  ('Armenia', 2015, Decimal('10.55')),
#  ('Armenia', 2016, Decimal('10.55')),
#  ('Armenia', 2017, Decimal('11.53')),
#  ('Armenia', 2018, Decimal('12.46')),
#  ('Armenia', 2019, Decimal('13.62')),
#  ('Armenia', 2020, Decimal('12.64')),
#  ('Azerbaijan', 2015, Decimal('53.07')),
#  ('Azerbaijan', 2016, Decimal('37.87')),
#  ('Azerbaijan', 2017, Decimal('40.87')),
#  ('Azerbaijan', 2018, Decimal('47.11')),
#  ('Azerbaijan', 2019, Decimal('48.17')),
#  ('Azerbaijan', 2020, Decimal('42.69')),
#  ('Bahrain', 2015, Decimal('31.05')),
#  ('Bahrain', 2016, Decimal('32.23')),
#  ('Bahrain', 2017, Decimal('35.47')),
#  ('Bahrain', 2018, Decimal('37.80')),
#  ('Bahrain', 2019, Decimal('38.65')),
#  ('Bahrain', 2020, Decimal('34.72')),
#  ('Cyprus', 2015, Decimal('19.91')),
#  ('Cyprus', 2016, Decimal('21.05')),
#  ('Cyprus', 2017, Decimal('22.95')),
#  ('Cyprus', 2018, Decimal('25.60')),
#  ('Cyprus', 2019, Decimal('25.94')),
#  ('Cyprus', 2020, Decimal('25.01')),
#  ('Georgia', 2015, Decimal('14.95')),
#  ('Georgia', 2016, Decimal('15.14')),
#  ('Georgia', 2017, Decimal('16.24')),
#  ('Georgia', 2018, Decimal('17.60')),
#  ('Georgia', 2019, Decimal('17.47')),
#  ('Georgia', 2020, Decimal('15.84')),
#  ('Iraq', 2015, Decimal('166.77')),
#  ('Iraq', 2016, Decimal('166.60')),
#  ('Iraq', 2017, Decimal('187.22')),
#  ('Iraq', 2018, Decimal('227.37')),
#  ('Iraq', 2019, Decimal('233.64')),
#  ('Iraq', 2020, Decimal('184.37')),
#  ('Israel', 2015, Decimal('303.41')),
#  ('Israel', 2016, Decimal('322.10')),
#  ('Israel', 2017, Decimal('358.25')),
#  ('Israel', 2018, Decimal('376.69')),
#  ('Israel', 2019, Decimal('402.47')),
#  ('Israel', 2020, Decimal('413.27')),
#  ('Jordan', 2015, Decimal('38.59')),
#  ('Jordan', 2016, Decimal('39.89')),
#  ('Jordan', 2017, Decimal('41.61')),
#  ('Jordan', 2018, Decimal('43.37')),
#  ('Jordan', 2019, Decimal('44.99')),
#  ('Jordan', 2020, Decimal('44.18')),
#  ('Kuwait', 2015, Decimal('114.57')),
#  ('Kuwait', 2016, Decimal('109.42')),
#  ('Kuwait', 2017, Decimal('120.71')),
#  ('Kuwait', 2018, Decimal('138.18')),
#  ('Kuwait', 2019, Decimal('136.20')),
#  ('Kuwait', 2020, Decimal('105.96')),
#  ('Lebanon', 2015, Decimal('49.93')),
#  ('Lebanon', 2016, Decimal('51.15')),
#  ('Lebanon', 2017, Decimal('53.03')),
#  ('Lebanon', 2018, Decimal('54.90')),
#  ('Lebanon', 2019, Decimal('51.95')),
#  ('Lebanon', 2020, Decimal('31.71')),
#  ('Oman', 2015, Decimal('78.71')),
#  ('Oman', 2016, Decimal('75.13')),
#  ('Oman', 2017, Decimal('80.86')),
#  ('Oman', 2018, Decimal('91.51')),
#  ('Oman', 2019, Decimal('88.06')),
#  ('Oman', 2020, Decimal('75.91')),
#  ('Qatar', 2015, Decimal('161.74')),
#  ('Qatar', 2016, Decimal('151.73')),
#  ('Qatar', 2017, Decimal('161.10')),
#  ('Qatar', 2018, Decimal('183.33')),
#  ('Qatar', 2019, Decimal('175.84')),
#  ('Qatar', 2020, Decimal('144.41')),
#  ('Saudi Arabia', 2015, Decimal('654.27')),
#  ('Saudi Arabia', 2016, Decimal('644.94')),
#  ('Saudi Arabia', 2017, Decimal('688.59')),
#  ('Saudi Arabia', 2018, Decimal('816.58')),
#  ('Saudi Arabia', 2019, Decimal('803.62')),
#  ('Saudi Arabia', 2020, Decimal('703.37')),
#  ('State of Palestine', 2015, None),
#  ('State of Palestine', 2016, None),
#  ('State of Palestine', 2017, None),
#  ('State of Palestine', 2018, None),
#  ('State of Palestine', 2019, None),
#  ('State of Palestine', 2020, None),
#  ('Syrian Arab Republic', 2015, Decimal('16.47')),
#  ('Syrian Arab Republic', 2016, Decimal('12.60')),
#  ('Syrian Arab Republic', 2017, Decimal('16.37')),
#  ('Syrian Arab Republic', 2018, Decimal('21.35')),
#  ('Syrian Arab Republic', 2019, Decimal('22.44')),
#  ('Syrian Arab Republic', 2020, Decimal('11.08')),
#  ('Türkiye', 2015, None),
#  ('Türkiye', 2016, None),
#  ('Türkiye', 2017, None),
#  ('Türkiye', 2018, None),
#  ('Türkiye', 2019, None),
#  ('Türkiye', 2020, None),
#  ('United Arab Emirates', 2015, Decimal('370.28')),
#  ('United Arab Emirates', 2016, Decimal('369.26')),
#  ('United Arab Emirates', 2017, Decimal('390.52')),
#  ('United Arab Emirates', 2018, Decimal('427.05')),
#  ('United Arab Emirates', 2019, Decimal('417.99')),
#  ('United Arab Emirates', 2020, Decimal('349.47')),
#  ('Yemen', 2015, None),
#  ('Yemen', 2016, None),
#  ('Yemen', 2017, None),
#  ('Yemen', 2018, None),
#  ('Yemen', 2019, None),
#  ('Yemen', 2020, None),
#  ('Australia', 2015, Decimal('1350.62')),
#  ('Australia', 2016, Decimal('1206.54')),
#  ('Australia', 2017, Decimal('1326.52')),
#  ('Australia', 2018, Decimal('1428.29')),
#  ('Australia', 2019, Decimal('1392.23')),
#  ('Australia', 2020, Decimal('1326.90')),
#  ('New Zealand', 2015, Decimal('178.06')),
#  ('New Zealand', 2016, Decimal('188.84')),
#  ('New Zealand', 2017, Decimal('206.62')),
#  ('New Zealand', 2018, Decimal('211.95')),
#  ('New Zealand', 2019, Decimal('213.43')),
#  ('New Zealand', 2020, Decimal('211.73')),
#  ('Fiji', 2015, Decimal('4.68')),
#  ('Fiji', 2016, Decimal('4.93')),
#  ('Fiji', 2017, Decimal('5.35')),
#  ('Fiji', 2018, Decimal('5.58')),
#  ('Fiji', 2019, Decimal('5.48')),
#  ('Fiji', 2020, Decimal('4.48')),
#  ('New Caledonia', 2015, Decimal('8.74')),
#  ('New Caledonia', 2016, Decimal('8.72')),
#  ('New Caledonia', 2017, Decimal('9.17')),
#  ('New Caledonia', 2018, Decimal('9.85')),
#  ('New Caledonia', 2019, Decimal('9.44')),
#  ('New Caledonia', 2020, Decimal('9.44')),
#  ('Papua New Guinea', 2015, Decimal('21.72')),
#  ('Papua New Guinea', 2016, Decimal('20.76')),
#  ('Papua New Guinea', 2017, Decimal('22.74')),
#  ('Papua New Guinea', 2018, Decimal('24.11')),
#  ('Papua New Guinea', 2019, Decimal('24.75')),
#  ('Papua New Guinea', 2020, Decimal('23.85')),
#  ('Solomon Islands', 2015, Decimal('1.31')),
#  ('Solomon Islands', 2016, Decimal('1.38')),
#  ('Solomon Islands', 2017, Decimal('1.47')),
#  ('Solomon Islands', 2018, Decimal('1.62')),
#  ('Solomon Islands', 2019, Decimal('1.62')),
#  ('Solomon Islands', 2020, Decimal('1.54')),
#  ('Vanuatu', 2015, Decimal('0.73')),
#  ('Vanuatu', 2016, Decimal('0.78')),
#  ('Vanuatu', 2017, Decimal('0.88')),
#  ('Vanuatu', 2018, Decimal('0.91')),
#  ('Vanuatu', 2019, Decimal('0.94')),
#  ('Vanuatu', 2020, Decimal('0.90')),
#  ('Guam', 2015, Decimal('5.80')),
#  ('Guam', 2016, Decimal('5.90')),
#  ('Guam', 2017, Decimal('6.01')),
#  ('Guam', 2018, Decimal('6.06')),
#  ('Guam', 2019, Decimal('6.37')),
#  ('Guam', 2020, Decimal('5.89')),
#  ('Kiribati', 2015, Decimal('0.17')),
#  ('Kiribati', 2016, Decimal('0.18')),
#  ('Kiribati', 2017, Decimal('0.19')),
#  ('Kiribati', 2018, Decimal('0.20')),
#  ('Kiribati', 2019, Decimal('0.18')),
#  ('Kiribati', 2020, Decimal('0.18')),
#  ('Marshall Islands', 2015, Decimal('0.18')),
#  ('Marshall Islands', 2016, Decimal('0.20')),
#  ('Marshall Islands', 2017, Decimal('0.21')),
#  ('Marshall Islands', 2018, Decimal('0.22')),
#  ('Marshall Islands', 2019, Decimal('0.23')),
#  ('Marshall Islands', 2020, Decimal('0.24')),
#  ('Micronesia (Federated States of)', 2015, None),
#  ('Micronesia (Federated States of)', 2016, None),
#  ('Micronesia (Federated States of)', 2017, None),
#  ('Micronesia (Federated States of)', 2018, None),
#  ('Micronesia (Federated States of)', 2019, None),
#  ('Nauru', 2015, Decimal('0.09')),
#  ('Nauru', 2016, Decimal('0.10')),
#  ('Nauru', 2017, Decimal('0.11')),
#  ('Nauru', 2018, Decimal('0.12')),
#  ('Nauru', 2019, Decimal('0.12')),
#  ('Nauru', 2020, Decimal('0.11')),
#  ('Northern Mariana Islands', 2015, Decimal('0.91')),
#  ('Northern Mariana Islands', 2016, Decimal('1.23')),
#  ('Northern Mariana Islands', 2017, Decimal('1.56')),
#  ('Northern Mariana Islands', 2018, Decimal('1.30')),
#  ('Northern Mariana Islands', 2019, Decimal('1.18')),
#  ('Northern Mariana Islands', 2020, None),
#  ('Palau', 2015, Decimal('0.28')),
#  ('Palau', 2016, Decimal('0.30')),
#  ('Palau', 2017, Decimal('0.29')),
#  ('Palau', 2018, Decimal('0.28')),
#  ('Palau', 2019, Decimal('0.28')),
#  ('Palau', 2020, Decimal('0.25')),
#  ('American Samoa', 2015, Decimal('0.67')),
#  ('American Samoa', 2016, Decimal('0.67')),
#  ('American Samoa', 2017, Decimal('0.61')),
#  ('American Samoa', 2018, Decimal('0.64')),
#  ('American Samoa', 2019, Decimal('0.65')),
#  ('American Samoa', 2020, Decimal('0.72')),
#  ('Cook Islands', 2015, None),
#  ('Cook Islands', 2016, None),
#  ('Cook Islands', 2017, None),
#  ('Cook Islands', 2018, None),
#  ('Cook Islands', 2019, None),
#  ('Cook Islands', 2020, None),
#  ('French Polynesia', 2015, Decimal('5.33')),
#  ('French Polynesia', 2016, Decimal('5.50')),
#  ('French Polynesia', 2017, Decimal('5.83')),
#  ('French Polynesia', 2018, Decimal('6.14')),
#  ('French Polynesia', 2019, Decimal('6.00')),
#  ('French Polynesia', 2020, Decimal('5.71')),
#  ('Niue', 2015, None),
#  ('Niue', 2016, None),
#  ('Niue', 2017, None),
#  ('Niue', 2018, None),
#  ('Niue', 2019, None),
#  ('Niue', 2020, None),
#  ('Samoa', 2015, Decimal('0.82')),
#  ('Samoa', 2016, Decimal('0.84')),
#  ('Samoa', 2017, Decimal('0.88')),
#  ('Samoa', 2018, Decimal('0.88')),
#  ('Samoa', 2019, Decimal('0.91')),
#  ('Samoa', 2020, Decimal('0.87')),
#  ('Tokelau', 2015, None),
#  ('Tokelau', 2016, None),
#  ('Tokelau', 2017, None),
#  ('Tokelau', 2018, None),
#  ('Tokelau', 2019, None),
#  ('Tokelau', 2020, None),
#  ('Tonga', 2015, Decimal('0.44')),
#  ('Tonga', 2016, Decimal('0.42')),
#  ('Tonga', 2017, Decimal('0.46')),
#  ('Tonga', 2018, Decimal('0.49')),
#  ('Tonga', 2019, Decimal('0.51')),
#  ('Tonga', 2020, Decimal('0.48')),
#  ('Tuvalu', 2015, Decimal('0.04')),
#  ('Tuvalu', 2016, Decimal('0.04')),
#  ('Tuvalu', 2017, Decimal('0.05')),
#  ('Tuvalu', 2018, Decimal('0.05')),
#  ('Tuvalu', 2019, Decimal('0.05')),
#  ('Tuvalu', 2020, Decimal('0.06')),
#  ('Wallis and Futuna Islands', 2015, None),
#  ('Wallis and Futuna Islands', 2016, None),
#  ('Wallis and Futuna Islands', 2017, None),
#  ('Wallis and Futuna Islands', 2018, None),
#  ('Wallis and Futuna Islands', 2019, None),
#  ('Wallis and Futuna Islands', 2020, None),
#  ('Burundi', 2015, Decimal('3.10')),
#  ('Burundi', 2016, Decimal('2.64')),
#  ('Burundi', 2017, Decimal('2.71')),
#  ('Burundi', 2018, Decimal('2.66')),
#  ('Burundi', 2019, Decimal('2.58')),
#  ('Burundi', 2020, Decimal('2.65')),
#  ('Comoros', 2015, Decimal('0.97')),
#  ('Comoros', 2016, Decimal('1.01')),
#  ('Comoros', 2017, Decimal('1.08')),
#  ('Comoros', 2018, Decimal('1.19')),
#  ('Comoros', 2019, Decimal('1.20')),
#  ('Djibouti', 2015, Decimal('2.42')),
#  ('Djibouti', 2016, Decimal('2.60')),
#  ('Djibouti', 2017, Decimal('2.76')),
#  ('Djibouti', 2018, Decimal('2.91')),
#  ('Djibouti', 2019, Decimal('3.09')),
#  ('Djibouti', 2020, Decimal('3.18')),
#  ('Eritrea', 2015, None),
#  ('Eritrea', 2016, None),
#  ('Ethiopia', 2015, Decimal('64.59')),
#  ('Ethiopia', 2016, Decimal('74.30')),
#  ('Ethiopia', 2017, Decimal('81.77')),
#  ('Ethiopia', 2018, Decimal('84.27')),
#  ('Ethiopia', 2019, Decimal('95.91')),
#  ('Ethiopia', 2020, Decimal('107.66')),
#  ('Kenya', 2015, Decimal('70.12')),
#  ('Kenya', 2016, Decimal('74.82')),
#  ('Kenya', 2017, Decimal('82.04')),
#  ('Kenya', 2018, Decimal('92.20')),
#  ('Kenya', 2019, Decimal('100.38')),
#  ('Kenya', 2020, Decimal('100.67')),
#  ('Madagascar', 2015, Decimal('11.32')),
#  ('Madagascar', 2016, Decimal('11.85')),
#  ('Madagascar', 2017, Decimal('13.18')),
#  ('Madagascar', 2018, Decimal('13.76')),
#  ('Madagascar', 2019, Decimal('14.10')),
#  ('Madagascar', 2020, Decimal('13.05')),
#  ('Malawi', 2015, Decimal('6.37')),
#  ('Malawi', 2016, Decimal('5.43')),
#  ('Malawi', 2017, Decimal('8.94')),
#  ('Malawi', 2018, Decimal('9.88')),
#  ('Malawi', 2019, Decimal('11.03')),
#  ('Malawi', 2020, Decimal('12.18')),
#  ('Mauritius', 2015, Decimal('12.01')),
#  ('Mauritius', 2016, Decimal('12.59')),
#  ('Mauritius', 2017, Decimal('13.71')),
#  ('Mauritius', 2018, Decimal('14.74')),
#  ('Mauritius', 2019, Decimal('14.44')),
#  ('Mauritius', 2020, Decimal('11.40')),
#  ('Mayotte', 2015, None),
#  ('Mayotte', 2016, None),
#  ('Mayotte', 2017, None),
#  ('Mayotte', 2018, None),
#  ('Mayotte', 2019, None),
#  ('Mayotte', 2020, None),
#  ('Mozambique', 2015, Decimal('15.95')),
#  ('Mozambique', 2016, Decimal('11.94')),
#  ('Mozambique', 2017, Decimal('13.22')),
#  ('Mozambique', 2018, Decimal('14.85')),
#  ('Mozambique', 2019, Decimal('15.39')),
#  ('Mozambique', 2020, Decimal('14.03')),
#  ('Rwanda', 2015, Decimal('8.54')),
#  ('Rwanda', 2016, Decimal('8.69')),
#  ('Rwanda', 2017, Decimal('9.25')),
#  ('Rwanda', 2018, Decimal('9.64')),
#  ('Rwanda', 2019, Decimal('10.36')),
#  ('Rwanda', 2020, Decimal('10.18')),
#  ('Réunion', 2015, None),
#  ('Réunion', 2016, None),
#  ('Réunion', 2017, None),
#  ('Réunion', 2018, None),
#  ('Réunion', 2019, None),
#  ('Réunion', 2020, None),
#  ('Seychelles', 2015, Decimal('1.42')),
#  ('Seychelles', 2016, Decimal('1.49')),
#  ('Seychelles', 2017, Decimal('1.57')),
#  ('Seychelles', 2018, Decimal('1.64')),
#  ('Seychelles', 2019, Decimal('1.68')),
#  ('Somalia', 2015, Decimal('5.33')),
#  ('Somalia', 2016, Decimal('5.53')),
#  ('Somalia', 2017, Decimal('5.61')),
#  ('Somalia', 2018, Decimal('5.86')),
#  ('Somalia', 2019, Decimal('6.49')),
#  ('Somalia', 2020, Decimal('6.88')),
#  ('South Sudan', 2015, Decimal('12.00')),
#  ('South Sudan', 2016, None),
#  ('South Sudan', 2017, None),
#  ('South Sudan', 2018, None),
#  ('South Sudan', 2019, None),
#  ('South Sudan', 2020, None),
#  ('Uganda', 2015, Decimal('32.39')),
#  ('Uganda', 2016, Decimal('29.20')),
#  ('Uganda', 2017, Decimal('30.74')),
#  ('Uganda', 2018, Decimal('32.93')),
#  ('Uganda', 2019, Decimal('35.35')),
#  ('Uganda', 2020, Decimal('37.60')),
#  ('United Republic of Tanzania', 2015, None),
#  ('United Republic of Tanzania', 2016, None),
#  ('United Republic of Tanzania', 2017, None),
#  ('United Republic of Tanzania', 2018, None),
#  ('United Republic of Tanzania', 2019, None),
#  ('United Republic of Tanzania', 2020, None),
#  ('Zambia', 2015, Decimal('21.25')),
#  ('Zambia', 2016, Decimal('20.96')),
#  ('Zambia', 2017, Decimal('25.87')),
#  ('Zambia', 2018, Decimal('26.31')),
#  ('Zambia', 2019, Decimal('23.31')),
#  ('Zambia', 2020, Decimal('18.11')),
#  ('Zimbabwe', 2015, Decimal('19.96')),
#  ('Zimbabwe', 2016, Decimal('20.55')),
#  ('Zimbabwe', 2017, Decimal('17.58')),
#  ('Zimbabwe', 2018, Decimal('34.16')),
#  ('Zimbabwe', 2019, Decimal('21.83')),
#  ('Zimbabwe', 2020, Decimal('21.51')),
#  ('Angola', 2015, Decimal('87.22')),
#  ('Angola', 2016, Decimal('49.84')),
#  ('Angola', 2017, Decimal('68.97')),
#  ('Angola', 2018, Decimal('77.79')),
#  ('Angola', 2019, Decimal('69.31')),
#  ('Angola', 2020, Decimal('53.62')),
#  ('Cameroon', 2015, Decimal('32.21')),
#  ('Cameroon', 2016, Decimal('33.81')),
#  ('Cameroon', 2017, Decimal('36.10')),
#  ('Cameroon', 2018, Decimal('39.97')),
#  ('Cameroon', 2019, Decimal('39.67')),
#  ('Cameroon', 2020, Decimal('40.77')),
#  ('Central African Republic', 2015, Decimal('1.70')),
#  ('Central African Republic', 2016, Decimal('1.83')),
#  ('Central African Republic', 2017, Decimal('2.07')),
#  ('Central African Republic', 2018, Decimal('2.22')),
#  ('Central African Republic', 2019, Decimal('2.22')),
#  ('Central African Republic', 2020, Decimal('2.33')),
#  ('Chad', 2015, Decimal('10.95')),
#  ('Chad', 2016, Decimal('10.10')),
#  ('Chad', 2017, Decimal('10.00')),
#  ('Chad', 2018, Decimal('11.24')),
#  ('Chad', 2019, Decimal('11.31')),
#  ('Chad', 2020, Decimal('10.72')),
#  ('Congo', 2015, None),
#  ('Congo', 2016, None),
#  ('Congo', 2017, None),
#  ('Congo', 2018, None),
#  ('Congo', 2019, None),
#  ('Congo', 2020, None),
#  ('Democratic Republic of the Congo', 2015, None),
#  ('Democratic Republic of the Congo', 2016, None),
#  ('Democratic Republic of the Congo', 2017, None),
#  ('Democratic Republic of the Congo', 2018, None),
#  ('Democratic Republic of the Congo', 2019, None),
#  ('Democratic Republic of the Congo', 2020, None),
#  ('Equatorial Guinea', 2015, Decimal('13.19')),
#  ('Equatorial Guinea', 2016, Decimal('11.24')),
#  ('Equatorial Guinea', 2017, Decimal('12.20')),
#  ('Gabon', 2015, Decimal('14.38')),
#  ('Gabon', 2016, Decimal('14.02')),
#  ('Gabon', 2017, Decimal('14.93')),
#  ('Gabon', 2018, Decimal('16.87')),
#  ('Gabon', 2019, Decimal('16.87')),
#  ('Gabon', 2020, Decimal('15.31')),
#  ('Sao Tome and Principe', 2015, Decimal('0.32')),
#  ('Sao Tome and Principe', 2016, Decimal('0.35')),
#  ('Sao Tome and Principe', 2017, Decimal('0.38')),
#  ('Sao Tome and Principe', 2018, Decimal('0.41')),
#  ('Sao Tome and Principe', 2019, Decimal('0.43')),
#  ('Sao Tome and Principe', 2020, Decimal('0.47')),
#  ('Botswana', 2015, Decimal('13.53')),
#  ('Botswana', 2016, Decimal('15.08')),
#  ('Botswana', 2017, Decimal('16.11')),
#  ('Botswana', 2018, Decimal('17.03')),
#  ('Botswana', 2019, Decimal('16.70')),
#  ('Botswana', 2020, Decimal('14.93')),
#  ('Eswatini', 2015, Decimal('4.06')),
#  ('Eswatini', 2016, Decimal('3.82')),
#  ('Eswatini', 2017, Decimal('4.40')),
#  ('Eswatini', 2018, Decimal('4.67')),
#  ('Eswatini', 2019, Decimal('4.50')),
#  ('Eswatini', 2020, Decimal('3.98')),
#  ('Lesotho', 2015, Decimal('2.36')),
#  ('Lesotho', 2016, Decimal('2.11')),
#  ('Lesotho', 2017, Decimal('2.31')),
#  ('Lesotho', 2018, Decimal('2.55')),
#  ('Lesotho', 2019, Decimal('2.45')),
#  ('Lesotho', 2020, Decimal('2.23')),
#  ('Namibia', 2015, Decimal('11.34')),
#  ('Namibia', 2016, Decimal('10.72')),
#  ('Namibia', 2017, Decimal('12.90')),
#  ('Namibia', 2018, Decimal('13.68')),
#  ('Namibia', 2019, Decimal('12.54')),
#  ('Namibia', 2020, Decimal('10.58')),
#  ('South Africa', 2015, Decimal('346.71')),
#  ('South Africa', 2016, Decimal('323.59')),
#  ('South Africa', 2017, Decimal('381.45')),
#  ('South Africa', 2018, Decimal('404.16')),
#  ('South Africa', 2019, Decimal('388.53')),
#  ('South Africa', 2020, Decimal('337.62')),
#  ('Benin', 2015, Decimal('11.39')),
#  ('Benin', 2016, Decimal('11.82')),
#  ('Benin', 2017, Decimal('12.70')),
#  ('Benin', 2018, Decimal('14.26')),
#  ('Benin', 2019, Decimal('14.39')),
#  ('Benin', 2020, Decimal('15.65')),
#  ('Burkina Faso', 2015, Decimal('11.83')),
#  ('Burkina Faso', 2016, Decimal('12.83')),
#  ('Burkina Faso', 2017, Decimal('14.11')),
#  ('Burkina Faso', 2018, Decimal('15.89')),
#  ('Burkina Faso', 2019, Decimal('16.18')),
#  ('Burkina Faso', 2020, Decimal('17.93')),
#  ('Cabo Verde', 2015, Decimal('1.60')),
#  ('Cabo Verde', 2016, Decimal('1.66')),
#  ('Cabo Verde', 2017, Decimal('1.77')),
#  ('Cabo Verde', 2018, Decimal('1.97')),
#  ('Cabo Verde', 2019, Decimal('1.98')),
#  ('Cabo Verde', 2020, Decimal('1.70')),
#  ("Côte d'Ivoire", 2015, None),
#  ("Côte d'Ivoire", 2016, None),
#  ("Côte d'Ivoire", 2017, None),
#  ("Côte d'Ivoire", 2018, None),
#  ("Côte d'Ivoire", 2019, None),
#  ("Côte d'Ivoire", 2020, None),
#  ('Gambia', 2015, None),
#  ('Gambia', 2016, None),
#  ('Gambia', 2017, None),
#  ('Gambia', 2018, None),
#  ('Gambia', 2019, None),
#  ('Gambia', 2020, None),
#  ('Ghana', 2015, Decimal('49.41')),
#  ('Ghana', 2016, Decimal('56.17')),
#  ('Ghana', 2017, Decimal('60.41')),
#  ('Ghana', 2018, Decimal('67.30')),
#  ('Ghana', 2019, Decimal('68.34')),
#  ('Ghana', 2020, Decimal('70.04')),
#  ('Guinea', 2015, Decimal('8.79')),
#  ('Guinea', 2016, Decimal('8.60')),
#  ('Guinea', 2017, Decimal('10.32')),
#  ('Guinea', 2018, Decimal('11.86')),
#  ('Guinea', 2019, Decimal('13.44')),
#  ('Guinea', 2020, Decimal('14.18')),
#  ('Guinea-Bissau', 2015, Decimal('1.05')),
#  ('Guinea-Bissau', 2016, Decimal('1.18')),
#  ('Guinea-Bissau', 2017, Decimal('1.35')),
#  ('Guinea-Bissau', 2018, Decimal('1.50')),
#  ('Guinea-Bissau', 2019, Decimal('1.44')),
#  ('Guinea-Bissau', 2020, Decimal('1.43')),
#  ('Liberia', 2015, Decimal('3.23')),
#  ('Liberia', 2016, Decimal('3.40')),
#  ('Liberia', 2017, Decimal('3.39')),
#  ('Liberia', 2018, Decimal('3.42')),
#  ('Liberia', 2019, Decimal('3.32')),
#  ('Liberia', 2020, Decimal('3.04')),
#  ...]

# %% [markdown]
# ### 2. What are the rounded-off values of the Est_gdp_in_billions column?
#
# When looking at many billion-dollar figures, the decimal places can be a little distracting. We can round off the numbers in the `Est_gdp_in_billions` column to make them more manageable.
#
# Using the same query executed above, round off the values in the `Est_gdp_in_billions` column using the `ROUND` function.

# %%
# %%sql
# SELECT
#     Time_period,
#     ROUND(Est_gdp_in_billions) AS Rounded_Est_gdp_billions
# FROM
#     united_nations.access_to_basic_services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [(2015, Decimal('184')),
#  (2016, Decimal('137')),
#  (2017, Decimal('167')),
#  (2018, Decimal('179')),
#  (2019, Decimal('182')),
#  (2020, Decimal('171')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('8')),
#  (2016, Decimal('7')),
#  (2017, Decimal('8')),
#  (2018, Decimal('8')),
#  (2019, Decimal('8')),
#  (2020, Decimal('8')),
#  (2015, Decimal('36')),
#  (2016, Decimal('36')),
#  (2017, Decimal('38')),
#  (2018, Decimal('41')),
#  (2019, Decimal('45')),
#  (2020, None),
#  (2015, Decimal('86')),
#  (2016, Decimal('86')),
#  (2017, Decimal('62')),
#  (2018, Decimal('53')),
#  (2019, Decimal('60')),
#  (2020, Decimal('60')),
#  (2015, Decimal('20')),
#  (2016, Decimal('18')),
#  (2017, Decimal('19')),
#  (2018, Decimal('18')),
#  (2019, Decimal('19')),
#  (2020, Decimal('20')),
#  (2015, Decimal('195')),
#  (2016, Decimal('265')),
#  (2017, Decimal('294')),
#  (2018, Decimal('321')),
#  (2019, Decimal('351')),
#  (2020, Decimal('374')),
#  (2015, Decimal('2')),
#  (2016, Decimal('2')),
#  (2017, Decimal('2')),
#  (2018, Decimal('2')),
#  (2019, Decimal('3')),
#  (2020, Decimal('2')),
#  (2015, Decimal('2104')),
#  (2016, Decimal('2295')),
#  (2017, Decimal('2651')),
#  (2018, Decimal('2703')),
#  (2019, Decimal('2832')),
#  (2020, Decimal('2668')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('4')),
#  (2016, Decimal('4')),
#  (2017, Decimal('5')),
#  (2018, Decimal('5')),
#  (2019, Decimal('6')),
#  (2020, Decimal('4')),
#  (2015, Decimal('24')),
#  (2016, Decimal('25')),
#  (2017, Decimal('29')),
#  (2018, Decimal('33')),
#  (2019, Decimal('34')),
#  (2020, Decimal('33')),
#  (2015, Decimal('271')),
#  (2016, Decimal('314')),
#  (2017, Decimal('339')),
#  (2018, Decimal('356')),
#  (2019, Decimal('321')),
#  (2020, Decimal('300')),
#  (2015, Decimal('85')),
#  (2016, Decimal('88')),
#  (2017, Decimal('94')),
#  (2018, Decimal('94')),
#  (2019, Decimal('89')),
#  (2020, Decimal('85')),
#  (2015, Decimal('11062')),
#  (2016, Decimal('11233')),
#  (2017, Decimal('12310')),
#  (2018, Decimal('13895')),
#  (2019, Decimal('14280')),
#  (2020, Decimal('14688')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('4445')),
#  (2016, Decimal('5004')),
#  (2017, Decimal('4931')),
#  (2018, Decimal('5038')),
#  (2019, Decimal('5123')),
#  (2020, Decimal('5040')),
#  (2015, Decimal('12')),
#  (2016, Decimal('11')),
#  (2017, Decimal('11')),
#  (2018, Decimal('13')),
#  (2019, Decimal('14')),
#  (2020, Decimal('13')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('13')),
#  (2016, Decimal('11')),
#  (2017, Decimal('12')),
#  (2018, Decimal('14')),
#  (2019, Decimal('13')),
#  (2020, Decimal('12')),
#  (2015, Decimal('18')),
#  (2016, Decimal('20')),
#  (2017, Decimal('22')),
#  (2018, Decimal('25')),
#  (2019, Decimal('27')),
#  (2020, Decimal('26')),
#  (2015, Decimal('861')),
#  (2016, Decimal('932')),
#  (2017, Decimal('1016')),
#  (2018, Decimal('1042')),
#  (2019, Decimal('1119')),
#  (2020, Decimal('1059')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('301')),
#  (2016, Decimal('301')),
#  (2017, Decimal('319')),
#  (2018, Decimal('359')),
#  (2019, Decimal('365')),
#  (2020, Decimal('337')),
#  (2015, Decimal('63')),
#  (2016, Decimal('60')),
#  (2017, Decimal('61')),
#  (2018, Decimal('67')),
#  (2019, Decimal('69')),
#  (2020, Decimal('79')),
#  (2015, Decimal('306')),
#  (2016, Decimal('319')),
#  (2017, Decimal('328')),
#  (2018, Decimal('347')),
#  (2019, Decimal('377')),
#  (2020, Decimal('362')),
#  (2015, Decimal('308')),
#  (2016, Decimal('319')),
#  (2017, Decimal('343')),
#  (2018, Decimal('377')),
#  (2019, Decimal('375')),
#  (2020, Decimal('345')),
#  (2015, Decimal('401')),
#  (2016, Decimal('413')),
#  (2017, Decimal('456')),
#  (2018, Decimal('507')),
#  (2019, Decimal('544')),
#  (2020, Decimal('500')),
#  (2015, Decimal('2')),
#  (2016, Decimal('2')),
#  (2017, Decimal('2')),
#  (2018, Decimal('2')),
#  (2019, Decimal('2')),
#  (2020, Decimal('2')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('7')),
#  (2016, Decimal('7')),
#  (2017, Decimal('7')),
#  (2018, Decimal('7')),
#  (2019, Decimal('7')),
#  (2020, Decimal('7')),
#  (2015, Decimal('1557')),
#  (2016, Decimal('1528')),
#  (2017, Decimal('1649')),
#  (2018, Decimal('1725')),
#  (2019, Decimal('1742')),
#  (2020, Decimal('1645')),
#  (2015, Decimal('3')),
#  (2016, Decimal('3')),
#  (2017, Decimal('3')),
#  (2018, Decimal('3')),
#  (2019, Decimal('3')),
#  (2020, Decimal('3')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2015, Decimal('1')),
#  (2016, Decimal('1')),
#  (2017, Decimal('1')),
#  (2015, Decimal('3')),
#  (2016, Decimal('3')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2015, Decimal('5')),
#  (2016, Decimal('5')),
#  (2017, Decimal('5')),
#  (2018, Decimal('5')),
#  (2019, Decimal('5')),
#  (2020, Decimal('5')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('5')),
#  (2016, Decimal('5')),
#  (2015, Decimal('87')),
#  (2016, Decimal('91')),
#  (2017, Decimal('97')),
#  (2018, Decimal('100')),
#  (2019, Decimal('103')),
#  (2020, Decimal('107')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2015, Decimal('1')),
#  (2016, Decimal('1')),
#  (2017, Decimal('1')),
#  (2015, Decimal('71')),
#  (2016, Decimal('76')),
#  (2017, Decimal('80')),
#  (2018, Decimal('86')),
#  (2019, Decimal('89')),
#  (2020, Decimal('79')),
#  (2015, Decimal('1')),
#  (2016, Decimal('1')),
#  (2017, Decimal('1')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('15')),
#  (2016, Decimal('14')),
#  (2017, Decimal('15')),
#  (2018, Decimal('16')),
#  (2019, Decimal('15')),
#  (2020, Decimal('15')),
#  (2015, Decimal('14')),
#  (2016, Decimal('14')),
#  (2017, Decimal('15')),
#  (2018, Decimal('16')),
#  (2019, Decimal('16')),
#  (2020, Decimal('14')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('103')),
#  (2016, Decimal('104')),
#  (2017, Decimal('103')),
#  (2018, Decimal('101')),
#  (2019, Decimal('105')),
#  (2020, Decimal('103')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2015, Decimal('1')),
#  (2016, Decimal('1')),
#  (2017, Decimal('1')),
#  (2015, Decimal('27')),
#  (2016, Decimal('24')),
#  (2017, Decimal('24')),
#  (2018, Decimal('24')),
#  (2019, Decimal('24')),
#  (2020, Decimal('21')),
#  (2015, Decimal('1')),
#  (2016, Decimal('1')),
#  (2017, Decimal('1')),
#  (2018, Decimal('1')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('2')),
#  (2016, Decimal('2')),
#  (2017, Decimal('2')),
#  (2018, Decimal('2')),
#  (2019, Decimal('2')),
#  (2020, Decimal('2')),
#  (2015, Decimal('56')),
#  (2016, Decimal('59')),
#  (2017, Decimal('61')),
#  (2018, Decimal('62')),
#  (2019, Decimal('64')),
#  (2020, Decimal('62')),
#  (2015, Decimal('23')),
#  (2016, Decimal('24')),
#  (2017, Decimal('25')),
#  (2018, Decimal('26')),
#  (2019, Decimal('27')),
#  (2020, Decimal('25')),
#  (2015, Decimal('62')),
#  (2016, Decimal('66')),
#  (2017, Decimal('72')),
#  (2018, Decimal('73')),
#  (2019, Decimal('77')),
#  (2020, Decimal('78')),
#  (2015, Decimal('21')),
#  (2016, Decimal('22')),
#  (2017, Decimal('23')),
#  (2018, Decimal('24')),
#  (2019, Decimal('25')),
#  (2020, Decimal('24')),
#  (2015, Decimal('1172')),
#  (2016, Decimal('1078')),
#  (2017, Decimal('1159')),
#  (2018, Decimal('1222')),
#  (2019, Decimal('1269')),
#  (2020, Decimal('1091')),
#  (2015, Decimal('13')),
#  (2016, Decimal('13')),
#  (2017, Decimal('14')),
#  (2018, Decimal('13')),
#  (2019, Decimal('13')),
#  (2020, Decimal('13')),
#  (2015, Decimal('54')),
#  (2016, Decimal('58')),
#  (2017, Decimal('62')),
#  (2018, Decimal('65')),
#  (2019, Decimal('67')),
#  (2020, Decimal('54')),
#  (2015, Decimal('595')),
#  (2016, Decimal('558')),
#  (2017, Decimal('644')),
#  (2018, Decimal('525')),
#  (2019, Decimal('448')),
#  (2020, Decimal('386')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('1802')),
#  (2016, Decimal('1796')),
#  (2017, Decimal('2064')),
#  (2018, Decimal('1917')),
#  (2019, Decimal('1873')),
#  (2020, Decimal('1449')),
#  (2015, Decimal('243')),
#  (2016, Decimal('249')),
#  (2017, Decimal('276')),
#  (2018, Decimal('295')),
#  (2019, Decimal('279')),
#  (2020, Decimal('253')),
#  (2015, Decimal('293')),
#  (2016, Decimal('283')),
#  (2017, Decimal('312')),
#  (2018, Decimal('334')),
#  (2019, Decimal('323')),
#  (2020, Decimal('270')),
#  (2015, Decimal('99')),
#  (2016, Decimal('100')),
#  (2017, Decimal('104')),
#  (2018, Decimal('108')),
#  (2019, Decimal('108')),
#  (2020, Decimal('99')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('4')),
#  (2016, Decimal('4')),
#  (2017, Decimal('5')),
#  (2018, Decimal('5')),
#  (2019, Decimal('5')),
#  (2020, Decimal('5')),
#  (2015, Decimal('36')),
#  (2016, Decimal('36')),
#  (2017, Decimal('39')),
#  (2018, Decimal('40')),
#  (2019, Decimal('38')),
#  (2020, Decimal('35')),
#  (2015, Decimal('190')),
#  (2016, Decimal('192')),
#  (2017, Decimal('211')),
#  (2018, Decimal('223')),
#  (2019, Decimal('228')),
#  (2020, Decimal('202')),
#  (2015, Decimal('5')),
#  (2016, Decimal('3')),
#  (2017, Decimal('4')),
#  (2018, Decimal('4')),
#  (2019, Decimal('4')),
#  (2020, Decimal('3')),
#  (2015, Decimal('53')),
#  (2016, Decimal('57')),
#  (2017, Decimal('64')),
#  (2018, Decimal('65')),
#  (2019, Decimal('61')),
#  (2020, Decimal('54')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('166')),
#  (2016, Decimal('160')),
#  (2017, Decimal('170')),
#  (2018, Decimal('175')),
#  (2019, Decimal('172')),
#  (2020, Decimal('145')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('49')),
#  (2016, Decimal('50')),
#  (2017, Decimal('67')),
#  (2018, Decimal('77')),
#  (2019, Decimal('69')),
#  (2020, Decimal('50')),
#  (2015, Decimal('110')),
#  (2016, Decimal('112')),
#  (2017, Decimal('119')),
#  (2018, Decimal('127')),
#  (2019, Decimal('129')),
#  (2020, Decimal('121')),
#  (2015, Decimal('85')),
#  (2016, Decimal('103')),
#  (2017, Decimal('130')),
#  (2018, Decimal('32')),
#  (2019, Decimal('32')),
#  (2020, Decimal('27')),
#  (2015, Decimal('46')),
#  (2016, Decimal('44')),
#  (2017, Decimal('42')),
#  (2018, Decimal('43')),
#  (2019, Decimal('42')),
#  (2020, Decimal('43')),
#  (2015, Decimal('11')),
#  (2016, Decimal('11')),
#  (2017, Decimal('12')),
#  (2018, Decimal('12')),
#  (2019, Decimal('14')),
#  (2020, Decimal('13')),
#  (2015, Decimal('53')),
#  (2016, Decimal('38')),
#  (2017, Decimal('41')),
#  (2018, Decimal('47')),
#  (2019, Decimal('48')),
#  (2020, Decimal('43')),
#  (2015, Decimal('31')),
#  (2016, Decimal('32')),
#  (2017, Decimal('35')),
#  (2018, Decimal('38')),
#  (2019, Decimal('39')),
#  (2020, Decimal('35')),
#  (2015, Decimal('20')),
#  (2016, Decimal('21')),
#  (2017, Decimal('23')),
#  (2018, Decimal('26')),
#  (2019, Decimal('26')),
#  (2020, Decimal('25')),
#  (2015, Decimal('15')),
#  (2016, Decimal('15')),
#  (2017, Decimal('16')),
#  (2018, Decimal('18')),
#  (2019, Decimal('17')),
#  (2020, Decimal('16')),
#  (2015, Decimal('167')),
#  (2016, Decimal('167')),
#  (2017, Decimal('187')),
#  (2018, Decimal('227')),
#  (2019, Decimal('234')),
#  (2020, Decimal('184')),
#  (2015, Decimal('303')),
#  (2016, Decimal('322')),
#  (2017, Decimal('358')),
#  (2018, Decimal('377')),
#  (2019, Decimal('402')),
#  (2020, Decimal('413')),
#  (2015, Decimal('39')),
#  (2016, Decimal('40')),
#  (2017, Decimal('42')),
#  (2018, Decimal('43')),
#  (2019, Decimal('45')),
#  (2020, Decimal('44')),
#  (2015, Decimal('115')),
#  (2016, Decimal('109')),
#  (2017, Decimal('121')),
#  (2018, Decimal('138')),
#  (2019, Decimal('136')),
#  (2020, Decimal('106')),
#  (2015, Decimal('50')),
#  (2016, Decimal('51')),
#  (2017, Decimal('53')),
#  (2018, Decimal('55')),
#  (2019, Decimal('52')),
#  (2020, Decimal('32')),
#  (2015, Decimal('79')),
#  (2016, Decimal('75')),
#  (2017, Decimal('81')),
#  (2018, Decimal('92')),
#  (2019, Decimal('88')),
#  (2020, Decimal('76')),
#  (2015, Decimal('162')),
#  (2016, Decimal('152')),
#  (2017, Decimal('161')),
#  (2018, Decimal('183')),
#  (2019, Decimal('176')),
#  (2020, Decimal('144')),
#  (2015, Decimal('654')),
#  (2016, Decimal('645')),
#  (2017, Decimal('689')),
#  (2018, Decimal('817')),
#  (2019, Decimal('804')),
#  (2020, Decimal('703')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('16')),
#  (2016, Decimal('13')),
#  (2017, Decimal('16')),
#  (2018, Decimal('21')),
#  (2019, Decimal('22')),
#  (2020, Decimal('11')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('370')),
#  (2016, Decimal('369')),
#  (2017, Decimal('391')),
#  (2018, Decimal('427')),
#  (2019, Decimal('418')),
#  (2020, Decimal('349')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('1351')),
#  (2016, Decimal('1207')),
#  (2017, Decimal('1327')),
#  (2018, Decimal('1428')),
#  (2019, Decimal('1392')),
#  (2020, Decimal('1327')),
#  (2015, Decimal('178')),
#  (2016, Decimal('189')),
#  (2017, Decimal('207')),
#  (2018, Decimal('212')),
#  (2019, Decimal('213')),
#  (2020, Decimal('212')),
#  (2015, Decimal('5')),
#  (2016, Decimal('5')),
#  (2017, Decimal('5')),
#  (2018, Decimal('6')),
#  (2019, Decimal('5')),
#  (2020, Decimal('4')),
#  (2015, Decimal('9')),
#  (2016, Decimal('9')),
#  (2017, Decimal('9')),
#  (2018, Decimal('10')),
#  (2019, Decimal('9')),
#  (2020, Decimal('9')),
#  (2015, Decimal('22')),
#  (2016, Decimal('21')),
#  (2017, Decimal('23')),
#  (2018, Decimal('24')),
#  (2019, Decimal('25')),
#  (2020, Decimal('24')),
#  (2015, Decimal('1')),
#  (2016, Decimal('1')),
#  (2017, Decimal('1')),
#  (2018, Decimal('2')),
#  (2019, Decimal('2')),
#  (2020, Decimal('2')),
#  (2015, Decimal('1')),
#  (2016, Decimal('1')),
#  (2017, Decimal('1')),
#  (2018, Decimal('1')),
#  (2019, Decimal('1')),
#  (2020, Decimal('1')),
#  (2015, Decimal('6')),
#  (2016, Decimal('6')),
#  (2017, Decimal('6')),
#  (2018, Decimal('6')),
#  (2019, Decimal('6')),
#  (2020, Decimal('6')),
#  (2015, Decimal('0')),
#  (2016, Decimal('0')),
#  (2017, Decimal('0')),
#  (2018, Decimal('0')),
#  (2019, Decimal('0')),
#  (2020, Decimal('0')),
#  (2015, Decimal('0')),
#  (2016, Decimal('0')),
#  (2017, Decimal('0')),
#  (2018, Decimal('0')),
#  (2019, Decimal('0')),
#  (2020, Decimal('0')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (
),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('1')),
#  (2016, Decimal('1')),
#  (2017, Decimal('2')),
#  (2018, Decimal('2')),
#  (2019, Decimal('2')),
#  (2015, Decimal('5')),
#  (2016, Decimal('6')),
#  (2017, Decimal('6')),
#  (2018, Decimal('6')),
#  (2019, Decimal('6')),
#  (2020, Decimal('7')),
#  (2015, Decimal('12')),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('32')),
#  (2016, Decimal('29')),
#  (2017, Decimal('31')),
#  (2018, Decimal('33')),
#  (2019, Decimal('35')),
#  (2020, Decimal('38')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('21')),
#  (2016, Decimal('21')),
#  (2017, Decimal('26')),
#  (2018, Decimal('26')),
#  (2019, Decimal('23')),
#  (2020, Decimal('18')),
#  (2015, Decimal('20')),
#  (2016, Decimal('21')),
#  (2017, Decimal('18')),
#  (2018, Decimal('34')),
#  (2019, Decimal('22')),
#  (2020, Decimal('22')),
#  (2015, Decimal('87')),
#  (2016, Decimal('50')),
#  (2017, Decimal('69')),
#  (2018, Decimal('78')),
#  (2019, Decimal('69')),
#  (2020, Decimal('54')),
#  (2015, Decimal('32')),
#  (2016, Decimal('34')),
#  (2017, Decimal('36')),
#  (2018, Decimal('40')),
#  (2019, Decimal('40')),
#  (2020, Decimal('41')),
#  (2015, Decimal('2')),
#  (2016, Decimal('2')),
#  (2017, Decimal('2')),
#  (2018, Decimal('2')),
#  (2019, Decimal('2')),
#  (2020, Decimal('2')),
#  (2015, Decimal('11')),
#  (2016, Decimal('10')),
#  (2017, Decimal('10')),
#  (2018, Decimal('11')),
#  (2019, Decimal('11')),
#  (2020, Decimal('11')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('13')),
#  (2016, Decimal('11')),
#  (2017, Decimal('12')),
#  (2015, Decimal('14')),
#  (2016, Decimal('14')),
#  (2017, Decimal('15')),
#  (2018, Decimal('17')),
#  (2019, Decimal('17')),
#  (2020, Decimal('15')),
#  (2015, Decimal('0')),
#  (2016, Decimal('0')),
#  (2017, Decimal('0')),
#  (2018, Decimal('0')),
#  (2019, Decimal('0')),
#  (2020, Decimal('0')),
#  (2015, Decimal('14')),
#  (2016, Decimal('15')),
#  (2017, Decimal('16')),
#  (2018, Decimal('17')),
#  (2019, Decimal('17')),
#  (2020, Decimal('15')),
#  (2015, Decimal('4')),
#  (2016, Decimal('4')),
#  (2017, Decimal('4')),
#  (2018, Decimal('5')),
#  (2019, Decimal('5')),
#  (2020, Decimal('4')),
#  (2015, Decimal('2')),
#  (2016, Decimal('2')),
#  (2017, Decimal('2')),
#  (2018, Decimal('3')),
#  (2019, Decimal('2')),
#  (2020, Decimal('2')),
#  (2015, Decimal('11')),
#  (2016, Decimal('11')),
#  (2017, Decimal('13')),
#  (2018, Decimal('14')),
#  (2019, Decimal('13')),
#  (2020, Decimal('11')),
#  (2015, Decimal('347')),
#  (2016, Decimal('324')),
#  (2017, Decimal('381')),
#  (2018, Decimal('404')),
#  (2019, Decimal('389')),
#  (2020, Decimal('338')),
#  (2015, Decimal('11')),
#  (2016, Decimal('12')),
#  (2017, Decimal('13')),
#  (2018, Decimal('14')),
#  (2019, Decimal('14')),
#  (2020, Decimal('16')),
#  (2015, Decimal('12')),
#  (2016, Decimal('13')),
#  (2017, Decimal('14')),
#  (2018, Decimal('16')),
#  (2019, Decimal('16')),
#  (2020, Decimal('18')),
#  (2015, Decimal('2')),
#  (2016, Decimal('2')),
#  (2017, Decimal('2')),
#  (2018, Decimal('2')),
#  (2019, Decimal('2')),
#  (2020, Decimal('2')),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, Decimal('49')),
#  (2016, Decimal('56')),
#  (2017, Decimal('60')),
#  (2018, Decimal('67')),
#  (2019, Decimal('68')),
#  (2020, Decimal('70')),
#  (2015, Decimal('9')),
#  (2016, Decimal('9')),
#  (2017, Decimal('10')),
#  (2018, Decimal('12')),
#  (2019, Decimal('13')),
#  (2020, Decimal('14')),
#  (2015, Decimal('1')),
#  (2016, Decimal('1')),
#  (2017, Decimal('1')),
#  (2018, Decimal('2')),
#  (2019, Decimal('1')),
#  (2020, Decimal('1')),
#  (2015, Decimal('3')),
#  (2016, Decimal('3')),
#  (2017, Decimal('3')),
#  (2018, Decimal('3')),
#  (2019, Decimal('3')),
#  (2020, Decimal('3')),
#  ...]

# %% [markdown]
# ### 3. What is the logarithm of GDP for each country over the time period?
#
# In order to calculate the growth rate of GDP over the time period, we can use the logarithm of GDP. This is because using the logarithm allows for easier comparison and analysis of growth rates with more digestible representations of larger numbers. Logarithmic transformations capture proportional changes rather than absolute changes, which is often more meaningful when analysing economic growth rates.
#
# Calculate the logarithmic of the `Est_gdp_in_billions` column using the LOG function.

# %%
# %%sql
# SELECT
#     Time_period,
#     LOG(Est_gdp_in_billions) AS LOG_Est_gdp_in_billions
# FROM
#     united_nations.access_to_basic_services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [(2015, 5.217053079717073),
#  (2016, 4.922022635739652),
#  (2017, 5.116855440165964),
#  (2018, 5.189283445523902),
#  (2019, 5.202191854450653),
#  (2020, 5.142131283358708),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, 2.1126345090356),
#  (2016, 1.944480556245719),
#  (2017, 2.020222182019865),
#  (2018, 2.050270164379556),
#  (2019, 2.1162555148025524),
#  (2020, 2.0955609235597192),
#  (2015, 3.5779478934066544),
#  (2016, 3.5882300459640066),
#  (2017, 3.6357423557008075),
#  (2018, 3.707946516831162),
#  (2019, 3.8117605834897517),
#  (2020, None),
#  (2015, 4.456670177669648),
#  (2016, 4.455973879625964),
#  (2017, 4.128423875874963),
#  (2018, 3.9632862993656874),
#  (2019, 4.0928434360958335),
#  (2020, 4.092509546276371),
#  (2015, 2.995732273553991),
#  (2016, 2.8914822521801917),
#  (2017, 2.9391619220655967),
#  (2018, 2.913437030827161),
#  (2019, 2.9391619220655967),
#  (2020, 3.0027078872904163),
#  (2015, 5.273409730841852),
#  (2016, 5.580635076500667),
#  (2017, 5.682729065458369),
#  (2018, 5.772624223613607),
#  (2019, 5.8614697504917945),
#  (2020, 5.923988381983068),
#  (2015, 0.6931471805599453),
#  (2016, 0.7701082216960737),
#  (2017, 0.8960880245566357),
#  (2018, 0.8960880245566357),
#  (2019, 0.9321640810304452),
#  (2020, 0.8458682675776092),
#  (2015, 7.651400687948423),
#  (2016, 7.738400972727716),
#  (2017, 7.88286948216281),
#  (2018, 7.902091648789797),
#  (2019, 7.948579543882852),
#  (2020, 7.888968208380664),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015,
#  (2017, 2.5572273113676265),
#  (2018, 2.615934912194404),
#  (2019, 2.5289235352047745),
#  (2020, 2.3589654264301534),
#  (2015, 5.848488695655459),
#  (2016, 5.779477282358271),
#  (2017, 5.943979780536238),
#  (2018, 6.001810839162126),
#  (2019, 5.962370386903605),
#  (2020, 5.821921002673243),
#  (2015, 2.432735777459091),
#  (2016, 2.469793011977952),
#  (2017, 2.5416019934645457),
#  (2018, 2.65745841498615),
#  (2019, 2.6665335208992764),
#  (2020, 2.750470916986162),
#  (2015, 2.4706386779902956),
#  (2016, 2.551786178627545),
#  (2017, 2.6468837658647226),
#  (2018, 2.7656899805486246),
#  (2019, 2.7837759116303458),
#  (2020, 2.8864752876170416),
#  (2015, 0.47000362924573563),
#  (2016, 0.5068176023684519),
#  (2017, 0.5709795465857378),
#  (2018, 0.6780335427498971),
#  (2019, 0.6830968447064438),
#  (2020, 0.5306282510621704),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, None),
#  (2016, None),
#  (2017, None),
#  (2018, None),
#  (2019, None),
#  (2020, None),
#  (2015, 3.9001528328576587),
#  (2016, 4.028382806544341),
#  (2017, 4.101154654150649),
#  (2018, 4.209160236650682),
#  (2019, 4.2244952466871455),
#  (2020, 4.249066507417651),
#  (2015, 2.1736147116970854),
#  (2016, 2.151762203259462),
#  (2017, 2.334083760053417),
#  (2018, 2.4731713935695794),
#  (2019, 2.5982353350950036),
#  (2020, 2.6518325211039815),
#  (2015, 0.04879016416943204),
#  (2016, 0.16551443847757333),
#  (2017, 0.30010459245033816),
#  (2018, 0.4054651081081644),
#  (2019, 0.36464311358790924),
#  (2020, 0.3576744442718159),
#  (2015, 1.172482137234565),
#  (2016, 1.2237754316221157),
#  (2017, 1.220829921392359),
#  (2018, 1.2296405510745139),
#  (2019, 1.199964782928397),
#  (2020, 1.1118575154181303),
#  ...]

# %% [markdown]
# ### 4. What is the square root of GDP for each country over the time period?
#
# Alternatively, to get a similar effect, we could use the `SQRT` function to calculate the square roots of the values in the `Est_gdp_in_billions` column in order to get a smaller representation of these values.
#
# Calculate the square root of the `Est_gdp_in_billions` column using the `SQRT` function.

# %%
# Add your code here

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. What is the GDP per year for each country??

# %%
# %%sql
#
# Select Country_name,
#     Time_period,
#     Est_gdp_in_billions
# FROM Access_to_Basic_Services;

# %% [markdown]
# ### 2. What are the rounded-off values of the Est_gdp_in_billions column?

# %%
# %%sql
#
# Select Country_name,
#     Time_period,
#     ROUND(Est_gdp_in_billions) AS Rounded_est_gdp_in_billions
# FROM Access_to_Basic_Services;

# %% [markdown]
# ### 3. What is the logarithm of GDP for each country over the time period?

# %%
# %%sql
#
# Select Country_name,
#     Time_period,
#     LOG(Est_gdp_in_billions) AS Log_est_gdp_in_billions
# FROM Access_to_Basic_Services;

# %% [markdown]
# ### 4. What is the square root of GDP for each country over the time period?

# %%
# %%sql
#
# Select Country_name,
#     Time_period,
#     SQRT(Est_gdp_in_billions) AS SQRT_est_gdp_in_billions
# FROM Access_to_Basic_Services;

# %% [markdown]
# ### Summary
#
# We can also combine all of our queries into a single query to have a single return that includes all of the values.

# %%
# %%sql
#
# Select Country_name,
#     Time_period,
#     ROUND(Est_gdp_in_billions),
#     LOG(Est_gdp_in_billions) AS Log_est_gdp_in_billions,
#     SQRT(Est_gdp_in_billions) AS SQRT_est_gdp_in_billions
# FROM Access_to_Basic_Services;

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
