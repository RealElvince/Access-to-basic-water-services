# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Recreating the Access_to_Basic_Services dataset

# %% [markdown]
# In this notebook, we cover how ERDs help us understand database joins better. We also focus on the `LEFT JOIN` technique and highlight the importance of picking the right joining strategy, as incorrect joins can lead to inaccurate results.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# By the end of this train, you will:
# - Understand how Entity-Relationship Diagrams can help us understand database joins better.
# - Understand the `LEFT JOIN` technique and how it is used to combine tables.
# - Know the importance of picking the right joining strategy and how incorrect joins can lead to inaccurate results.

# %% [markdown]
# ## Overview
#
# Entity-Relationship diagrams play a valuable role in determining the table relationships and join strategies within a database. They provide the means to make informed decisions about which tables to join and the appropriate method for doing so.
#
#
# Let’s recall our united_nations ERD which has three entities: Geographic_Location, Basic_Services, and Economic_Indicators.
#
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Northwind_ERD.png" alt= "united_nations ERD" width="60%" height="60%">

# %% [markdown]
# One common joining technique involves selecting a central table that serves as the core of all relationships in the database and employing a `LEFT JOIN`.
# In our case, the `Geographic_Location` table would be the central table.
#
# With a `LEFT JOIN`, all records from the left table are returned, along with the corresponding matching records from the right table. In cases where there is no match, the result will include NULL values on the right side.

# %% [markdown]
# ## Connecting to our MySQL database
#
# We'll start by connecting to the `united_nations` database. To connect to the MySQL server, run the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
import os
from dotenv import load_dotenv
load_dotenv()

DB_NAME = os.getenv("DB_NAME")
DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT")
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")


conn = f"mysql+pymysql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
# %sql $conn
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# We'll then use a simple `SELECT` query to fetch all records from the `Geographic_Location` table.

# %%
# %%sql
# SELECT
# 	*
# FROM
# 	united_nations.Geographic_Location as geo
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00')),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None)]

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. First `LEFT JOIN`
#
# Combine the `Geographic_Location` table with the `Economic_Indicators` table based on the `Country_name` column.

# %%
# %%sql
# SELECT
#     *
# FROM
#     united_nations.Geographic_Location g
#
# LEFT JOIN
#     united_nations.Economic_Indicators e
# ON
#     g.Country_name = e.Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.753499'), None),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.636207'), None),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.643418'), Decimal('11.18')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2018, Decimal('18.42'), Decimal('36.686784'), None),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2019, Decimal('18.90'), Decimal('37.769499'), None),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2020, Decimal('20.14'), Decimal('38.972230'), Decimal('11.71')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2015, Decimal('165.98'), Decimal('39.543154'), Decimal('11.21')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2016, Decimal('160.03'), Decimal('40.339329'), Decimal('10.20')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2017, Decimal('170.10'), Decimal('41.136546'), Decimal('12.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2018, Decimal('174.91'), Decimal('41.927007'), None),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2019, Decimal('171.77'), Decimal('42.705368'), None),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2020, Decimal('145.01'), Decimal('43.451666'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2015, Decimal('0.67'), Decimal('0.051368'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2016, Decimal('0.67'), Decimal('0.050448'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2017, Decimal('0.61'), Decimal('0.049463'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2018, Decimal('0.64'), Decimal('0.048424'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2019, Decimal('0.65'), Decimal('0.047321'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2020, Decimal('0.72'), Decimal('0.046189'), None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2015, Decimal('87.22'), Decimal('28.127721'), None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2016, Decimal('49.84'), Decimal('29.154746'), None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2017, Decimal('68.97'), Decimal('30.208628'), None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2018, Decimal('77.79'), Decimal('31.273533'), None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2019, Decimal('69.31'), Decimal('32.353588'), Decimal('16.50')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2020, Decimal('53.62'), Decimal('33.428486'), None),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, 'Anguilla', 2015, None, None, None),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, 'Anguilla', 2016, None, None, None),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, 'Anguilla', 2017, None, None, None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), 'Antigua and Barbuda', 2015, Decimal('1.34'), Decimal('0.089941'), None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), 'Antigua and Barbuda', 2016, Decimal('1.44'), Decimal('0.090564'), None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), 'Antigua and Barbuda', 2017, Decimal('1.47'), Decimal('0.091119'), None),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2015, Decimal('594.75'), Decimal('43.131966'), None),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2016, Decimal('557.53'), Decimal('43.590368'), None),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2017, Decimal('643.63'), Decimal('44.044811'), Decimal('8.35')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2018, Decimal('524.82'), Decimal('44.494502'), Decimal('9.22')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2019, Decimal('447.75'), Decimal('44.938712'), Decimal('9.84')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2020, Decimal('385.54'), Decimal('45.376763'), Decimal('11.46')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2015, Decimal('10.55'), Decimal('2.878595'), Decimal('18.26')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2016, Decimal('10.55'), Decimal('2.865835'), Decimal('17.62')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2017, Decimal('11.53'), Decimal('2.851923'), Decimal('17.70')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2018, Decimal('12.46'), Decimal('2.836557'), Decimal('13.21')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2019, Decimal('13.62'), Decimal('2.820602'), Decimal('12.20')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2020, Decimal('12.64'), Decimal('2.805608'), Decimal('12.18')),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', Decimal('180.00'), 'Aruba', 2015, Decimal('2.96'), Decimal('0.104257'), None),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', Decimal('180.00'), 'Aruba', 2016, Decimal('2.98'), Decimal('0.104874'), None),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2015, Decimal('1350.62'), Decimal('23.815995'), Decimal('6.06')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2016, Decimal('1206.54'), Decimal('24.190907'), Decimal('5.71')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2017, Decimal('1326.52'), Decimal('24.594202'), Decimal('5.59')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2018, Decimal('1428.29'), Decimal('24.966643'), Decimal('5.30')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2019, Decimal('1392.23'), Decimal('25.340217'), Decimal('5.16')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2020, Decimal('1326.90'), Decimal('25.655289'), Decimal('6.46')),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82658.17'), 'Azerbaijan', 2015, Decimal('53.07'), Decimal('9.649341'), Decimal('4.96')),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82658.17'), 'Azerbaijan', 2016, Decimal('37.87'), Decimal('9.757812'), Decimal('5.00')),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82658.17'), 'Azerbaijan', 2017, Decimal('40.87'), Decimal('9.854033'), Decimal('4.96')),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82658.17'), 'Azerbaijan', 2018, Decimal('47.11'), Decimal('9.939771'), Decimal('4.94')),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82658.17'), 'Azerbaijan', 2019, Decimal('48.17'), Decimal('10.024283'), Decimal('4.85')),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82658.17'), 'Azerbaijan', 2020, Decimal('42.69'), Decimal('10.093121'), Decimal('7.16')),
#  ('Bahamas', 'Caribbean', 'Latin America and the Caribbean', None, 'Bahamas', 2015, None, None, None),
#  ('Bahamas', 'Caribbean', 'Latin America and the Caribbean', None, 'Bahamas', 2016, None, None, None),
#  ('Bahamas', 'Caribbean', 'Latin America and the Caribbean', None, 'Bahamas', 2017, None, None, None),
#  ('Bahamas', 'Caribbean', 'Latin America and the Caribbean', None, 'Bahamas', 2018, None, None, None),
#  ('Bahamas', 'Caribbean', 'Latin America and the Caribbean', None, 'Bahamas', 2019, None, None, None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('780.83'), 'Bahrain', 2015, Decimal('31.05'), Decimal('1.362142'), None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('780.83'), 'Bahrain', 2016, Decimal('32.23'), Decimal('1.409661'), None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('780.83'), 'Bahrain', 2017, Decimal('35.47'), Decimal('1.456834'), None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('780.83'), 'Bahrain', 2018, Decimal('37.80'), Decimal('1.487340'), None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('780.83'), 'Bahrain', 2019, Decimal('38.65'), Decimal('1.494188'), None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('780.83'), 'Bahrain', 2020, Decimal('34.72'), Decimal('1.477469'), None),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.00'), 'Bangladesh', 2015, Decimal('195.08'), Decimal('157.830000'), None),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.00'), 'Bangladesh', 2016, Decimal('265.24'), Decimal('159.784568'), Decimal('4.35')),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.00'), 'Bangladesh', 2017, Decimal('293.75'), Decimal('161.793964'), Decimal('4.37')),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.00'), 'Bangladesh', 2018, Decimal('321.38'), Decimal('163.683958'), None),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.00'), 'Bangladesh', 2019, Decimal('351.24'), Decimal('165.516222'), None),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.00'), 'Bangladesh', 2020, Decimal('373.90'), Decimal('167.420951'), None),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.00'), 'Barbados', 2015, Decimal('4.72'), Decimal('0.278083'), Decimal('9.80')),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.00'), 'Barbados', 2016, Decimal('4.83'), Decimal('0.278649'), Decimal('8.25')),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.00'), 'Barbados', 2017, Decimal('4.98'), Decimal('0.279187'), Decimal('8.62')),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.00'), 'Barbados', 2018, Decimal('5.10'), Decimal('0.279688'), Decimal('8.32')),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.00'), 'Barbados', 2019, Decimal('5.32'), Decimal('0.280180'), Decimal('8.41')),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.00'), 'Barbados', 2020, Decimal('4.67'), Decimal('0.280693'), None),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.00'), 'Belize', 2015, Decimal('2.21'), Decimal('0.359871'), Decimal('7.58')),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.00'), 'Belize', 2016, Decimal('2.26'), Decimal('0.367313'), Decimal('7.00')),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.00'), 'Belize', 2017, Decimal('2.29'), Decimal('0.374693'), Decimal('6.60')),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.00'), 'Belize', 2018, Decimal('2.31'), Decimal('0.382066'), None),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.00'), 'Belize', 2019, Decimal('2.42'), Decimal('0.389095'), Decimal('9.05')),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.00'), 'Belize', 2020, Decimal('2.08'), Decimal('0.394921'), None),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.00'), 'Benin', 2015, Decimal('11.39'), Decimal('10.932783'), None),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.00'), 'Benin', 2016, Decimal('11.82'), Decimal('11.260085'), None),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.00'), 'Benin', 2017, Decimal('12.70'), Decimal('11.596779'), None),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.00'), 'Benin', 2018, Decimal('14.26'), Decimal('11.940683'), Decimal('1.47')),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.00'), 'Benin', 2019, Decimal('14.39'), Decimal('12.290444'), None),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.00'), 'Benin', 2020, Decimal('15.65'), Decimal('12.643123'), None),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.00'), 'Bermuda', 2015, Decimal('6.65'), Decimal('0.065237'), None),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.00'), 'Bermuda', 2016, Decimal('6.90'), Decimal('0.064554'), None),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.00'), 'Bermuda', 2017, Decimal('7.14'), Decimal('0.063873'), None),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.00'), 'Bermuda', 2018, Decimal('7.23'), Decimal('0.063918'), None),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.00'), 'Bermuda', 2019, Decimal('7.42'), Decimal('0.063911'), None),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.00'), 'Bermuda', 2020, Decimal('6.89'), Decimal('0.063893'), None),
#  ('Bhutan', 'Southern Asia', 'Central and Southern Asia', Decimal('38137.50'), 'Bhutan', 2015, Decimal('2.00'), Decimal('0.743274'), Decimal('2.45')),
#  ('Bhutan', 'Southern Asia', 'Central and Southern Asia', Decimal('38137.50'), 'Bhutan', 2016, Decimal('2.16'), Decimal('0.749761'), None),
#  ('Bhutan', 'Southern Asia', 'Central and Southern Asia', Decimal('38137.50'), 'Bhutan', 2017, Decimal('2.45'), Decimal('0.756121'), None),
#  ('Bhutan', 'Southern Asia', 'Central and Southern Asia', Decimal('38137.50'), 'Bhutan', 2018, Decimal('2.45'), Decimal('0.762096'), Decimal('3.35')),
#  ('Bhutan', 'Southern Asia', 'Central and Southern Asia', Decimal('38137.50'), 'Bhutan', 2019, Decimal('2.54'), Decimal('0.767459'), Decimal('2.72')),
#  ('Bhutan', 'Southern Asia', 'Central and Southern Asia', Decimal('38137.50'), 'Bhutan', 2020, Decimal('2.33'), Decimal('0.772506'), Decimal('5.03')),
#  ('Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', None, 'Bolivia (Plurinational State of)', 2015, None, None, None),
#  ('Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', None, 'Bolivia (Plurinational State of)', 2016, None, None, None),
#  ('Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', None, 'Bolivia (Plurinational State of)', 2017, None, None, None),
#  ('Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', None, 'Bolivia (Plurinational State of)', 2018, None, None, None),
#  ('Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', None, 'Bolivia (Plurinational State of)', 2019, None, None, None),
#  ('Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', None, 'Bolivia (Plurinational State of)', 2020, None, None, None),
#  ('Botswana', 'Southern Africa', 'Sub-Saharan Africa', Decimal('566730.00'), 'Botswana', 2015, Decimal('13.53'), Decimal('2.305171'), None),
#  ('Botswana', 'Southern Africa', 'Sub-Saharan Africa', Decimal('566730.00'), 'Botswana', 2016, Decimal('15.08'), Decimal('2.352416'), None),
#  ('Botswana', 'Southern Africa', 'Sub-Saharan Africa', Decimal('566730.00'), 'Botswana', 2017, Decimal('16.11'), Decimal('2.401840'), None),
#  ('Botswana', 'Southern Africa', 'Sub-Saharan Africa', Decimal('566730.00'), 'Botswana', 2018, Decimal('17.03'), Decimal('2.451409'), None),
#  ('Botswana', 'Southern Africa', 'Sub-Saharan Africa', Decimal('566730.00'), 'Botswana', 2019, Decimal('16.70'), Decimal('2.499702'), Decimal('20.09')),
#  ('Botswana', 'Southern Africa', 'Sub-Saharan Africa', Decimal('566730.00'), 'Botswana', 2020, Decimal('14.93'), Decimal('2.546402'), Decimal('21.02')),
#  ('Brazil', 'South America', 'Latin America and the Caribbean', Decimal('8358140.00'), 'Brazil', 2015, Decimal('1802.21'), Decimal('205.188205'), Decimal('8.54')),
#  ('Brazil', 'South America', 'Latin America and the Caribbean', Decimal('8358140.00'), 'Brazil', 2016, Decimal('1795.70'), Decimal('206.859578'), Decimal('11.58')),
#  ('Brazil', 'South America', 'Latin America and the Caribbean', Decimal('8358140.00'), 'Brazil', 2017, Decimal('2063.51'), Decimal('208.504960'), Decimal('12.79')),
#  ('Brazil', 'South America', 'Latin America and the Caribbean', Decimal('8358140.00'), 'Brazil', 2018, Decimal('1916.95'), Decimal('210.166592'), Decimal('12.33')),
#  ('Brazil', 'South America', 'Latin America and the Caribbean', Decimal('8358140.00'), 'Brazil', 2019, Decimal('1873.27'), Decimal('211.782878'), Decimal('11.94')),
#  ('Brazil', 'South America', 'Latin America and the Caribbean', Decimal('8358140.00'), 'Brazil', 2020, Decimal('1448.56'), Decimal('213.196304'), Decimal('13.70')),
#  ('British Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('150.00'), 'British Virgin Islands', 2015, None, Decimal('0.029366'), None),
#  ('British Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('150.00'), 'British Virgin Islands', 2016, None, Decimal('0.029739'), None),
#  ('British Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('150.00'), 'British Virgin Islands', 2017, None, Decimal('0.030060'), None),
#  ('British Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('150.00'), 'British Virgin Islands', 2018, None, Decimal('0.030335'), None),
#  ('British Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('150.00'), 'British Virgin Islands', 2019, None, Decimal('0.030610'), None),
#  ('British Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('150.00'), 'British Virgin Islands', 2020, None, Decimal('0.030910'), None),
#  ('Brunei Darussalam', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('5270.00'), 'Brunei Darussalam', 2015, Decimal('12.93'), Decimal('0.421437'), None),
#  ('Brunei Darussalam', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('5270.00'), 'Brunei Darussalam', 2016, Decimal('11.40'), Decimal('0.425994'), None),
#  ('Brunei Darussalam', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('5270.00'), 'Brunei Darussalam', 2017, Decimal('12.13'), Decimal('0.430276'), Decimal('9.32')),
#  ('Brunei Darussalam', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('5270.00'), 'Brunei Darussalam', 2018, Decimal('13.57'), Decimal('0.434274'), Decimal('8.70')),
#  ('Brunei Darussalam', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('5270.00'), 'Brunei Darussalam', 2019, Decimal('13.47'), Decimal('0.438048'), Decimal('6.60')),
#  ('Brunei Darussalam', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('5270.00'), 'Brunei Darussalam', 2020, Decimal('12.01'), Decimal('0.441725'), Decimal('7.41')),
#  ('Burkina Faso', 'Western Africa', 'Sub-Saharan Africa', Decimal('273600.00'), 'Burkina Faso', 2015, Decimal('11.83'), Decimal('18.718019'), None),
#  ('Burkina Faso', 'Western Africa', 'Sub-Saharan Africa', Decimal('273600.00'), 'Burkina Faso', 2016, Decimal('12.83'), Decimal('19.275498'), None),
#  ('Burkina Faso', 'Western Africa', 'Sub-Saharan Africa', Decimal('273600.00'), 'Burkina Faso', 2017, Decimal('14.11'), Decimal('19.835858'), None),
#  ('Burkina Faso', 'Western Africa', 'Sub-Saharan Africa', Decimal('273600.00'), 'Burkina Faso', 2018, Decimal('15.89'), Decimal('20.392723'), Decimal('4.69')),
#  ('Burkina Faso', 'Western Africa', 'Sub-Saharan Africa', Decimal('273600.00'), 'Burkina Faso', 2019, Decimal('16.18'), Decimal('20.951639'), None),
#  ('Burkina Faso', 'Western Africa', 'Sub-Saharan Africa', Decimal('273600.00'), 'Burkina Faso', 2020, Decimal('17.93'), Decimal('21.522626'), None),
#  ('Burundi', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('25680.00'), 'Burundi', 2015, Decimal('3.10'), Decimal('10.727148'), None),
#  ('Burundi', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('25680.00'), 'Burundi', 2016, Decimal('2.64'), Decimal('10.903327'), None),
#  ('Burundi', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('25680.00'), 'Burundi', 2017, Decimal('2.71'), Decimal('11.155593'), None),
#  ('Burundi', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('25680.00'), 'Burundi', 2018, Decimal('2.66'), Decimal('11.493472'), None),
#  ('Burundi', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('25680.00'), 'Burundi', 2019, Decimal('2.58'), Decimal('11.874838'), None),
#  ('Burundi', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('25680.00'), 'Burundi', 2020, Decimal('2.65'), Decimal('12.220227'), Decimal('1.03')),
#  ('Cabo Verde', 'Western Africa', 'Sub-Saharan Africa', Decimal('4030.00'), 'Cabo Verde', 2015, Decimal('1.60'), Decimal('0.552166'), Decimal('31.31')),
#  ('Cabo Verde', 'Western Africa', 'Sub-Saharan Africa', Decimal('4030.00'), 'Cabo Verde', 2016, Decimal('1.66'), Decimal('0.558394'), None),
#  ('Cabo Verde', 'Western Africa', 'Sub-Saharan Africa', Decimal('4030.00'), 'Cabo Verde', 2017, Decimal('1.77'), Decimal('0.564954'), Decimal('12.24')),
#  ('Cabo Verde', 'Western Africa', 'Sub-Saharan Africa', Decimal('4030.00'), 'Cabo Verde', 2018, Decimal('1.97'), Decimal('0.571202'), Decimal('12.17')),
#  ('Cabo Verde', 'Western Africa', 'Sub-Saharan Africa', Decimal('4030.00'), 'Cabo Verde', 2019, Decimal('1.98'), Decimal('0.577030'), Decimal('11.29')),
#  ('Cabo Verde', 'Western Africa', 'Sub-Saharan Africa', Decimal('4030.00'), 'Cabo Verde', 2020, Decimal('1.70'), Decimal('0.582640'), None),
#  ('Cambodia', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('176520.00'), 'Cambodia', 2015, Decimal('18.05'), Decimal('15.417523'), Decimal('0.39')),
#  ('Cambodia', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('176520.00'), 'Cambodia', 2016, Decimal('20.02'), Decimal('15.624584'), Decimal('0.72')),
#  ('Cambodia', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('176520.00'), 'Cambodia', 2017, Decimal('22.18'), Decimal('15.830689'), Decimal('0.14')),
#  ('Cambodia', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('176520.00'), 'Cambodia', 2018, Decimal('24.57'), Decimal('16.025238'), None),
#  ('Cambodia', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('176520.00'), 'Cambodia', 2019, Decimal('27.09'), Decimal('16.207746'), Decimal('0.50')),
#  ('Cambodia', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('176520.00'), 'Cambodia', 2020, Decimal('25.87'), Decimal('16.396860'), None),
#  ('Cameroon', 'Middle Africa', 'Sub-Saharan Africa', Decimal('472710.00'), 'Cameroon', 2015, Decimal('32.21'), Decimal('23.012646'), None),
#  ('Cameroon', 'Middle Africa', 'Sub-Saharan Africa', Decimal('472710.00'), 'Cameroon', 2016, Decimal('33.81'), Decimal('23.711630'), None),
#  ('Cameroon', 'Middle Africa', 'Sub-Saharan Africa', Decimal('472710.00'), 'Cameroon', 2017, Decimal('36.10'), Decimal('24.393181'), None),
#  ('Cameroon', 'Middle Africa', 'Sub-Saharan Africa', Decimal('472710.00'), 'Cameroon', 2018, Decimal('39.97'), Decimal('25.076747'), None),
#  ('Cameroon', 'Middle Africa', 'Sub-Saharan Africa', Decimal('472710.00'), 'Cameroon', 2019, Decimal('39.67'), Decimal('25.782341'), None),
#  ('Cameroon', 'Middle Africa', 'Sub-Saharan Africa', Decimal('472710.00'), 'Cameroon', 2020, Decimal('40.77'), Decimal('26.491087'), None),
#  ('Canada', 'Northern America', 'Europe and Northern America', Decimal('8965590.00'), 'Canada', 2015, Decimal('1556.51'), Decimal('35.702908'), Decimal('6.91')),
#  ('Canada', 'Northern America', 'Europe and Northern America', Decimal('8965590.00'), 'Canada', 2016, Decimal('1527.99'), Decimal('36.109487'), Decimal('7.00')),
#  ('Canada', 'Northern America', 'Europe and Northern America', Decimal('8965590.00'), 'Canada', 2017, Decimal('1649.27'), Decimal('36.545236'), Decimal('6.34')),
#  ('Canada', 'Northern America', 'Europe and Northern America', Decimal('8965590.00'), 'Canada', 2018, Decimal('1725.33'), Decimal('37.065084'), Decimal('5.83')),
#  ('Canada', 'Northern America', 'Europe and Northern America', Decimal('8965590.00'), 'Canada', 2019, Decimal('1742.02'), Decimal('37.601230'), Decimal('5.66')),
#  ('Canada', 'Northern America', 'Europe and Northern America', Decimal('8965590.00'), 'Canada', 2020, Decimal('1645.42'), Decimal('38.037204'), Decimal('9.46')),
#  ('Cayman Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('240.00'), 'Cayman Islands', 2015, Decimal('4.71'), Decimal('0.060911'), Decimal('4.24')),
#  ('Cayman Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('240.00'), 'Cayman Islands', 2016, Decimal('4.91'), Decimal('0.062255'), None),
#  ('Central African Republic', 'Middle Africa', 'Sub-Saharan Africa', Decimal('622980.00'), 'Central African Republic', 2015, Decimal('1.70'), Decimal('4.819333'), None),
#  ('Central African Republic', 'Middle Africa', 'Sub-Saharan Africa', Decimal('622980.00'), 'Central African Republic', 2016, Decimal('1.83'), Decimal('4.904177'), None),
#  ('Central African Republic', 'Middle Africa', 'Sub-Saharan Africa', Decimal('622980.00'), 'Central African Republic', 2017, Decimal('2.07'), Decimal('4.996741'), None),
#  ('Central African Republic', 'Middle Africa', 'Sub-Saharan Africa', Decimal('622980.00'), 'Central African Republic', 2018, Decimal('2.22'), Decimal('5.094780'), None),
#  ('Central African Republic', 'Middle Africa', 'Sub-Saharan Africa', Decimal('622980.00'), 'Central African Republic', 2019, Decimal('2.22'), Decimal('5.209324'), None),
#  ('Central African Republic', 'Middle Africa', 'Sub-Saharan Africa', Decimal('622980.00'), 'Central African Republic', 2020, Decimal('2.33'), Decimal('5.343020'), None),
#  ('Chad', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1259200.00'), 'Chad', 2015, Decimal('10.95'), Decimal('14.140274'), None),
#  ('Chad', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1259200.00'), 'Chad', 2016, Decimal('10.10'), Decimal('14.592585'), None),
#  ('Chad', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1259200.00'), 'Chad', 2017, Decimal('10.00'), Decimal('15.085884'), None),
#  ('Chad', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1259200.00'), 'Chad', 2018, Decimal('11.24'), Decimal('15.604210'), Decimal('1.13')),
#  ('Chad', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1259200.00'), 'Chad', 2019, Decimal('11.31'), Decimal('16.126866'), None),
#  ('Chad', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1259200.00'), 'Chad', 2020, Decimal('10.72'), Decimal('16.644701'), None),
#  ('Chile', 'South America', 'Latin America and the Caribbean', Decimal('743532.00'), 'Chile', 2015, Decimal('242.50'), Decimal('17.870124'), Decimal('6.49')),
#  ('Chile', 'South America', 'Latin America and the Caribbean', Decimal('743532.00'), 'Chile', 2016, Decimal('249.30'), Decimal('18.083879'), Decimal('6.73')),
#  ('Chile', 'South America', 'Latin America and the Caribbean', Decimal('743532.00'), 'Chile', 2017, Decimal('276.36'), Decimal('18.368577'), Decimal('6.95')),
#  ('Chile', 'South America', 'Latin America and the Caribbean', Decimal('743532.00'), 'Chile', 2018, Decimal('295.40'), Decimal('18.701450'), Decimal('7.21')),
#  ('Chile', 'South America', 'Latin America and the Caribbean', Decimal('743532.00'), 'Chile', 2019, Decimal('278.58'), Decimal('19.039485'), Decimal('7.27')),
#  ('Chile', 'South America', 'Latin America and the Caribbean', Decimal('743532.00'), 'Chile', 2020, Decimal('252.73'), Decimal('19.300315'), Decimal('10.94')),
#  ('China', 'Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('9424701.90'), 'China', 2015, Decimal('11061.55'), Decimal('1379.860000'), None),
#  ('China', 'Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('9424701.90'), 'China', 2016, Decimal('11233.28'), Decimal('1387.790000'), None),
#  ('China', 'Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('9424701.90'), 'China', 2017, Decimal('12310.41'), Decimal('1396.215000'), Decimal('3.90')),
#  ('China', 'Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('9424701.90'), 'China', 2018, Decimal('13894.82'), Decimal('1402.760000'), Decimal('4.93')),
#  ('China', 'Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('9424701.90'), 'China', 2019, Decimal('14279.94'), Decimal('1407.745000'), Decimal('5.15')),
#  ('China', 'Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('9424701.90'), 'China', 2020, Decimal('14687.67'), Decimal('1411.100000'), Decimal('5.61')),
#  ('Colombia', 'South America', 'Latin America and the Caribbean', Decimal('1109500.00'), 'Colombia', 2015, Decimal('293.48'), Decimal('47.119728'), Decimal('8.57')),
#  ('Colombia', 'South America', 'Latin America and the Caribbean', Decimal('1109500.00'), 'Colombia', 2016, Decimal('282.83'), Decimal('47.625955'), Decimal('8.92')),
#  ('Colombia', 'South America', 'Latin America and the Caribbean', Decimal('1109500.00'), 'Colombia', 2017, Decimal('311.88'), Decimal('48.351671'), Decimal('9.09')),
#  ('Colombia', 'South America', 'Latin America and the Caribbean', Decimal('1109500.00'), 'Colombia', 2018, Decimal('334.20'), Decimal('49.276961'), Decimal('9.36')),
#  ('Colombia', 'South America', 'Latin America and the Caribbean', Decimal('1109500.00'), 'Colombia', 2019, Decimal('323.11'), Decimal('50.187406'), Decimal('10.28')),
#  ('Colombia', 'South America', 'Latin America and the Caribbean', Decimal('1109500.00'), 'Colombia', 2020, Decimal('270.30'), Decimal('50.930662'), Decimal('15.98')),
#  ('Comoros', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('1861.00'), 'Comoros', 2015, Decimal('0.97'), Decimal('0.730216'), None),
#  ('Comoros', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('1861.00'), 'Comoros', 2016, Decimal('1.01'), Decimal('0.746232'), None),
#  ('Comoros', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('1861.00'), 'Comoros', 2017, Decimal('1.08'), Decimal('0.761664'), None),
#  ('Comoros', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('1861.00'), 'Comoros', 2018, Decimal('1.19'), Decimal('0.776313'), None),
#  ('Comoros', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('1861.00'), 'Comoros', 2019, Decimal('1.20'), Decimal('0.790986'), None),
#  ('Congo', 'Middle Africa', 'Sub-Saharan Africa', None, 'Congo', 2015, None, None, None),
#  ('Congo', 'Middle Africa', 'Sub-Saharan Africa', None, 'Congo', 2016, None, None, None),
#  ('Congo', 'Middle Africa', 'Sub-Saharan Africa', None, 'Congo', 2017, None, None, None),
#  ('Congo', 'Middle Africa', 'Sub-Saharan Africa', None, 'Congo', 2018, None, None, None),
#  ('Congo', 'Middle Africa', 'Sub-Saharan Africa', None, 'Congo', 2019, None, None, None),
#  ('Congo', 'Middle Africa', 'Sub-Saharan Africa', None, 'Congo', 2020, None, None, None),
#  ('Cook Islands', 'Polynesia', 'Oceania', None, 'Cook Islands', 2015, None, None, None),
#  ('Cook Islands', 'Polynesia', 'Oceania', None, 'Cook Islands', 2016, None, None, None),
#  ('Cook Islands', 'Polynesia', 'Oceania', None, 'Cook Islands', 2017, None, None, None),
#  ('Cook Islands', 'Polynesia', 'Oceania', None, 'Cook Islands', 2018, None, None, None),
#  ('Cook Islands', 'Polynesia', 'Oceania', None, 'Cook Islands', 2019, None, None, None),
#  ('Cook Islands', 'Polynesia', 'Oceania', None, 'Cook Islands', 2020, None, None, None),
#  ('Costa Rica', 'Central America', 'Latin America and the Caribbean', Decimal('51060.00'), 'Costa Rica', 2015, Decimal('56.44'), Decimal('4.895242'), Decimal('8.42')),
#  ('Costa Rica', 'Central America', 'Latin America and the Caribbean', Decimal('51060.00'), 'Costa Rica', 2016, Decimal('58.85'), Decimal('4.945205'), Decimal('8.09')),
#  ('Costa Rica', 'Central America', 'Latin America and the Caribbean', Decimal('51060.00'), 'Costa Rica', 2017, Decimal('60.52'), Decimal('4.993842'), Decimal('7.73')),
#  ('Costa Rica', 'Central America', 'Latin America and the Caribbean', Decimal('51060.00'), 'Costa Rica', 2018, Decimal('62.42'), Decimal('5.040734'), Decimal('9.01')),
#  ('Costa Rica', 'Central America', 'Latin America and the Caribbean', Decimal('51060.00'), 'Costa Rica', 2019, Decimal('64.42'), Decimal('5.084532'), Decimal('10.81')),
#  ('Costa Rica', 'Central America', 'Latin America and the Caribbean', Decimal('51060.00'), 'Costa Rica', 2020, Decimal('62.16'), Decimal('5.123105'), Decimal('16.43')),
#  ("Côte d'Ivoire", 'Western Africa', 'Sub-Saharan Africa', None, "Côte d'Ivoire", 2015, None, None, None),
#  ("Côte d'Ivoire", 'Western Africa', 'Sub-Saharan Africa', None, "Côte d'Ivoire", 2016, None, None, None),
#  ("Côte d'Ivoire", 'Western Africa', 'Sub-Saharan Africa', None, "Côte d'Ivoire", 2017, None, None, None),
#  ("Côte d'Ivoire", 'Western Africa', 'Sub-Saharan Africa', None, "Côte d'Ivoire", 2018, None, None, None),
#  ("Côte d'Ivoire", 'Western Africa', 'Sub-Saharan Africa', None, "Côte d'Ivoire", 2019, None, None, None),
#  ("Côte d'Ivoire", 'Western Africa', 'Sub-Saharan Africa', None, "Côte d'Ivoire", 2020, None, None, None),
#  ('Cuba', 'Caribbean', 'Latin America and the Caribbean', Decimal('103890.00'), 'Cuba', 2015, Decimal('87.13'), Decimal('11.339894'), Decimal('2.40')),
#  ('Cuba', 'Caribbean', 'Latin America and the Caribbean', Decimal('103890.00'), 'Cuba', 2016, Decimal('91.37'), Decimal('11.342012'), Decimal('2.00')),
#  ('Cuba', 'Caribbean', 'Latin America and the Caribbean', Decimal('103890.00'), 'Cuba', 2017, Decimal('96.85'), Decimal('11.336405'), Decimal('1.70')),
#  ('Cuba', 'Caribbean', 'Latin America and the Caribbean', Decimal('103890.00'), 'Cuba', 2018, Decimal('100.05'), Decimal('11.328244'), Decimal('1.70')),
#  ('Cuba', 'Caribbean', 'Latin America and the Caribbean', Decimal('103890.00'), 'Cuba', 2019, Decimal('103.43'), Decimal('11.316697'), None),
#  ('Cuba', 'Caribbean', 'Latin America and the Caribbean', Decimal('103890.00'), 'Cuba', 2020, Decimal('107.35'), Decimal('11.300698'), None),
#  ('Curaçao', 'Caribbean', 'Latin America and the Caribbean', None, 'Curaçao', 2015, None, None, None),
#  ('Curaçao', 'Caribbean', 'Latin America and the Caribbean', None, 'Curaçao', 2016, None, None, None),
#  ('Curaçao', 'Caribbean', 'Latin America and the Caribbean', None, 'Curaçao', 2017, None, None, None),
#  ('Cyprus', 'Western Asia', 'Northern Africa and Western Asia', Decimal('9240.00'), 'Cyprus', 2015, Decimal('19.91'), Decimal('1.187280'), Decimal('15.03')),
#  ('Cyprus', 'Western Asia', 'Northern Africa and Western Asia', Decimal('9240.00'), 'Cyprus', 2016, Decimal('21.05'), Decimal('1.197881'), Decimal('13.01')),
#  ('Cyprus', 'Western Asia', 'Northern Africa and Western Asia', Decimal('9240.00'), 'Cyprus', 2017, Decimal('22.95'), Decimal('1.208523'), Decimal('11.16')),
#  ('Cyprus', 'Western Asia', 'Northern Africa and Western Asia', Decimal('9240.00'), 'Cyprus', 2018, Decimal('25.60'), Decimal('1.218831'), Decimal('8.50')),
#  ('Cyprus', 'Western Asia', 'Northern Africa and Western Asia', Decimal('9240.00'), 'Cyprus', 2019, Decimal('25.94'), Decimal('1.228836'), Decimal('7.15')),
#  ('Cyprus', 'Western Asia', 'Northern Africa and Western Asia', Decimal('9240.00'), 'Cyprus', 2020, Decimal('25.01'), Decimal('1.237537'), Decimal('7.76')),
#  ("Democratic People's Republic of Korea", 'Eastern Asia', 'Eastern and South-Eastern Asia', None, "Democratic People's Republic of Korea", 2015, None, None, None),
#  ("Democratic People's Republic of Korea", 'Eastern Asia', 'Eastern and South-Eastern Asia', None, "Democratic People's Republic of Korea", 2016, None, None, None),
#  ("Democratic People's Republic of Korea", 'Eastern Asia', 'Eastern and South-Eastern Asia', None, "Democratic People's Republic of Korea", 2017, None, None, None),
#  ("Democratic People's Republic of Korea", 'Eastern Asia', 'Eastern and South-Eastern Asia', None, "Democratic People's Republic of Korea", 2018, None, None, None),
#  ("Democratic People's Republic of Korea", 'Eastern Asia', 'Eastern and South-Eastern Asia', None, "Democratic People's Republic of Korea", 2019, None, None, None),
#  ("Democratic People's Republic of Korea", 'Eastern Asia', 'Eastern and South-Eastern Asia', None, "Democratic People's Republic of Korea", 2020, None, None, None),
#  ('Democratic Republic of the Congo', 'Middle Africa', 'Sub-Saharan Africa', None, 'Democratic Republic of the Congo', 2015, None, None, None),
#  ('Democratic Republic of the Congo', 'Middle Africa', 'Sub-Saharan Africa', None, 'Democratic Republic of the Congo', 2016, None, None, None),
#  ('Democratic Republic of the Congo', 'Middle Africa', 'Sub-Saharan Africa', None, 'Democratic Republic of the Congo', 2017, None, None, None),
#  ('Democratic Republic of the Congo', 'Middle Africa', 'Sub-Saharan Africa', None, 'Democratic Republic of the Congo', 2018, None, None, None),
#  ('Democratic Republic of the Congo', 'Middle Africa', 'Sub-Saharan Africa', None, 'Democratic Republic of the Congo', 2019, None, None, None),
#  ('Democratic Republic of the Congo', 'Middle Africa', 'Sub-Saharan Africa', None, 'Democratic Republic of the Congo', 2020, None, None, None),
#  ('Djibouti', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('23180.00'), 'Djibouti', 2015, Decimal('2.42'), Decimal('1.006259'), None),
#  ('Djibouti', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('23180.00'), 'Djibouti', 2016, Decimal('2.60'), Decimal('1.023261'), None),
#  ('Djibouti', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('23180.00'), 'Djibouti', 2017, Decimal('2.76'), Decimal('1.040233'), Decimal('26.06')),
#  ('Djibouti', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('23180.00'), 'Djibouti', 2018, Decimal('2.91'), Decimal('1.057198'), None),
#  ('Djibouti', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('23180.00'), 'Djibouti', 2019, Decimal('3.09'), Decimal('1.073994'), None),
#  ('Djibouti', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('23180.00'), 'Djibouti', 2020, Decimal('3.18'), Decimal('1.090156'), None),
#  ('Dominica', 'Caribbean', 'Latin America and the Caribbean', Decimal('750.00'), 'Dominica', 2015, Decimal('0.54'), Decimal('0.070007'), None),
#  ('Dominica', 'Caribbean', 'Latin America and the Caribbean', Decimal('750.00'), 'Dominica', 2016, Decimal('0.58'), Decimal('0.070075'), None),
#  ('Dominica', 'Caribbean', 'Latin America and the Caribbean', Decimal('750.00'), 'Dominica', 2017, Decimal('0.52'), Decimal('0.070403'), None),
#  ('Dominican Republic', 'Caribbean', 'Latin America and the Caribbean', Decimal('48310.00'), 'Dominican Republic', 2015, Decimal('71.16'), Decimal('10.405832'), Decimal('7.61')),
#  ('Dominican Republic', 'Caribbean', 'Latin America and the Caribbean', Decimal('48310.00'), 'Dominican Republic', 2016, Decimal('75.70'), Decimal('10.527592'), Decimal('7.28')),
#  ('Dominican Republic', 'Caribbean', 'Latin America and the Caribbean', Decimal('48310.00'), 'Dominican Republic', 2017, Decimal('80.00'), Decimal('10.647244'), Decimal('5.83')),
#  ('Dominican Republic', 'Caribbean', 'Latin America and the Caribbean', Decimal('48310.00'), 'Dominican Republic', 2018, Decimal('85.56'), Decimal('10.765531'), Decimal('5.86')),
#  ('Dominican Republic', 'Caribbean', 'Latin America and the Caribbean', Decimal('48310.00'), 'Dominican Republic', 2019, Decimal('88.94'), Decimal('10.881882'), Decimal('6.18')),
#  ('Dominican Republic', 'Caribbean', 'Latin America and the Caribbean', Decimal('48310.00'), 'Dominican Republic', 2020, Decimal('78.84'), Decimal('10.999664'), Decimal('6.13')),
#  ('Ecuador', 'South America', 'Latin America and the Caribbean', Decimal('248360.00'), 'Ecuador', 2015, Decimal('99.29'), Decimal('16.195902'), Decimal('3.62')),
#  ('Ecuador', 'South America', 'Latin America and the Caribbean', Decimal('248360.00'), 'Ecuador', 2016, Decimal('99.94'), Decimal('16.439585'), Decimal('4.60')),
#  ('Ecuador', 'South America', 'Latin America and the Caribbean', Decimal('248360.00'), 'Ecuador', 2017, Decimal('104.30'), Decimal('16.696944'), Decimal('3.84')),
#  ('Ecuador', 'South America', 'Latin America and the Caribbean', Decimal('248360.00'), 'Ecuador', 2018, Decimal('107.56'), Decimal('17.015672'), Decimal('3.53')),
#  ('Ecuador', 'South America', 'Latin America and the Caribbean', Decimal('248360.00'), 'Ecuador', 2019, Decimal('108.11'), Decimal('17.343740'), Decimal('3.81')),
#  ('Ecuador', 'South America', 'Latin America and the Caribbean', Decimal('248360.00'), 'Ecuador', 2020, Decimal('99.29'), Decimal('17.588595'), Decimal('6.11')),
#  ('Egypt', 'Northern Africa', 'Northern Africa and Western Asia', None, 'Egypt', 2015, None, None, None),
#  ('Egypt', 'Northern Africa', 'Northern Africa and Western Asia', None, 'Egypt', 2016, None, None, None),
#  ('Egypt', 'Northern Africa', 'Northern Africa and Western Asia', None, 'Egypt', 2017, None, None, None),
#  ('Egypt', 'Northern Africa', 'Northern Africa and Western Asia', None, 'Egypt', 2018, None, None, None),
#  ('Egypt', 'Northern Africa', 'Northern Africa and Western Asia', None, 'Egypt', 2019, None, None, None),
#  ('Egypt', 'Northern Africa', 'Northern Africa and Western Asia', None, 'Egypt', 2020, None, None, None),
#  ('El Salvador', 'Central America', 'Latin America and the Caribbean', Decimal('20720.00'), 'El Salvador', 2015, Decimal('23.44'), Decimal('6.231066'), Decimal('4.00')),
#  ('El Salvador', 'Central America', 'Latin America and the Caribbean', Decimal('20720.00'), 'El Salvador', 2016, Decimal('24.19'), Decimal('6.250510'), Decimal('4.42')),
#  ('El Salvador', 'Central America', 'Latin America and the Caribbean', Decimal('20720.00'), 'El Salvador', 2017, Decimal('24.98'), Decimal('6.266654'), Decimal('4.39')),
#  ('El Salvador', 'Central America', 'Latin America and the Caribbean', Decimal('20720.00'), 'El Salvador', 2018, Decimal('26.02'), Decimal('6.276342'), Decimal('4.01')),
#  ('El Salvador', 'Central America', 'Latin America and the Caribbean', Decimal('20720.00'), 'El Salvador', 2019, Decimal('26.88'), Decimal('6.280217'), Decimal('4.17')),
#  ('El Salvador', 'Central America', 'Latin America and the Caribbean', Decimal('20720.00'), 'El Salvador', 2020, Decimal('24.56'), Decimal('6.292731'), Decimal('5.01')),
#  ('Equatorial Guinea', 'Middle Africa', 'Sub-Saharan Africa', Decimal('28050.00'), 'Equatorial Guinea', 2015, Decimal('13.19'), Decimal('1.346973'), None),
#  ('Equatorial Guinea', 'Middle Africa', 'Sub-Saharan Africa', Decimal('28050.00'), 'Equatorial Guinea', 2016, Decimal('11.24'), Decimal('1.398927'), None),
#  ('Equatorial Guinea', 'Middle Africa', 'Sub-Saharan Africa', Decimal('28050.00'), 'Equatorial Guinea', 2017, Decimal('12.20'), Decimal('1.450694'), None),
#  ('Eritrea', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('121083.12'), 'Eritrea', 2015, None, Decimal('3.340006'), None),
#  ('Eritrea', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('121083.12'), 'Eritrea', 2016, None, Decimal('3.365287'), None),
#  ('Eswatini', 'Southern Africa', 'Sub-Saharan Africa', Decimal('17200.00'), 'Eswatini', 2015, Decimal('4.06'), Decimal('1.133936'), None),
#  ('Eswatini', 'Southern Africa', 'Sub-Saharan Africa', Decimal('17200.00'), 'Eswatini', 2016, Decimal('3.82'), Decimal('1.142524'), Decimal('22.72')),
#  ('Eswatini', 'Southern Africa', 'Sub-Saharan Africa', Decimal('17200.00'), 'Eswatini', 2017, Decimal('4.40'), Decimal('1.151390'), None),
#  ('Eswatini', 'Southern Africa', 'Sub-Saharan Africa', Decimal('17200.00'), 'Eswatini', 2018, Decimal('4.67'), Decimal('1.160428'), None),
#  ('Eswatini', 'Southern Africa', 'Sub-Saharan Africa', Decimal('17200.00'), 'Eswatini', 2019, Decimal('4.50'), Decimal('1.169613'), None),
#  ('Eswatini', 'Southern Africa', 'Sub-Saharan Africa', Decimal('17200.00'), 'Eswatini', 2020, Decimal('3.98'), Decimal('1.180655'), None),
#  ('Ethiopia', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('1128559.04'), 'Ethiopia', 2015, Decimal('64.59'), Decimal('102.471895'), None),
#  ('Ethiopia', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('1128559.04'), 'Ethiopia', 2016, Decimal('74.30'), Decimal('105.293228'), None),
#  ('Ethiopia', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('1128559.04'), 'Ethiopia', 2017, Decimal('81.77'), Decimal('108.197950'), None),
#  ('Ethiopia', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('1128559.04'), 'Ethiopia', 2018, Decimal('84.27'), Decimal('111.129438'), None),
#  ('Ethiopia', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('1128559.04'), 'Ethiopia', 2019, Decimal('95.91'), Decimal('114.120594'), None),
#  ('Ethiopia', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('1128559.04'), 'Ethiopia', 2020, Decimal('107.66'), Decimal('117.190911'), None),
#  ('Falkland Islands (Malvinas)', 'South America', 'Latin America and the Caribbean', None, 'Falkland Islands (Malvinas)', 2015, None, None, None),
#  ('Falkland Islands (Malvinas)', 'South America', 'Latin America and the Caribbean', None, 'Falkland Islands (Malvinas)', 2016, None, None, None),
#  ('Falkland Islands (Malvinas)', 'South America', 'Latin America and the Caribbean', None, 'Falkland Islands (Malvinas)', 2017, None, None, None),
#  ('Falkland Islands (Malvinas)', 'South America', 'Latin America and the Caribbean', None, 'Falkland Islands (Malvinas)', 2018, None, None, None),
#  ('Falkland Islands (Malvinas)', 'South America', 'Latin America and the Caribbean', None, 'Falkland Islands (Malvinas)', 2019, None, None, None),
#  ('Falkland Islands (Malvinas)', 'South America', 'Latin America and the Caribbean', None, 'Falkland Islands (Malvinas)', 2020, None, None, None),
#  ('Fiji', 'Melanesia', 'Oceania', Decimal('18270.00'), 'Fiji', 2015, Decimal('4.68'), Decimal('0.917200'), None),
#  ('Fiji', 'Melanesia', 'Oceania', Decimal('18270.00'), 'Fiji', 2016, Decimal('4.93'), Decimal('0.918371'), Decimal('4.32')),
#  ('Fiji', 'Melanesia', 'Oceania', Decimal('18270.00'), 'Fiji', 2017, Decimal('5.35'), Decimal('0.919019'), None),
#  ('Fiji', 'Melanesia', 'Oceania', Decimal('18270.00'), 'Fiji', 2018, Decimal('5.58'), Decimal('0.918996'), None),
#  ('Fiji', 'Melanesia', 'Oceania', Decimal('18270.00'), 'Fiji', 2019, Decimal('5.48'), Decimal('0.918465'), None),
#  ('Fiji', 'Melanesia', 'Oceania', Decimal('18270.00'), 'Fiji', 2020, Decimal('4.48'), Decimal('0.920422'), None),
#  ('French Guiana', 'South America', 'Latin America and the Caribbean', None, 'French Guiana', 2015, None, None, None),
#  ('French Guiana', 'South America', 'Latin America and the Caribbean', None, 'French Guiana', 2016, None, None, None),
#  ('French Guiana', 'South America', 'Latin America and the Caribbean', None, 'French Guiana', 2017, None, None, None),
#  ('French Guiana', 'South America', 'Latin America and the Caribbean', None, 'French Guiana', 2018, None, None, None),
#  ('French Guiana', 'South America', 'Latin America and the Caribbean', None, 'French Guiana', 2019, None, None, None),
#  ('French Guiana', 'South America', 'Latin America and the Caribbean', None, 'French Guiana', 2020, None, None, None),
#  ('French Polynesia', 'Polynesia', 'Oceania', Decimal('3471.00'), 'French Polynesia', 2015, Decimal('5.33'), Decimal('0.291787'), None),
# ...
#  ('Syrian Arab Republic', 'Western Asia', 'Northern Africa and Western Asia', Decimal('183630.00'), 'Syrian Arab Republic', 2018, Decimal('21.35'), Decimal('19.333463'), None),
#  ('Syrian Arab Republic', 'Western Asia', 'Northern Africa and Western Asia', Decimal('183630.00'), 'Syrian Arab Republic', 2019, Decimal('22.44'), Decimal('20.098251'), None),
#  ('Syrian Arab Republic', 'Western Asia', 'Northern Africa and Western Asia', Decimal('183630.00'), 'Syrian Arab Republic', 2020, Decimal('11.08'), Decimal('20.772595'), None),
#  ('Tajikistan', 'Central Asia', 'Central and Southern Asia', Decimal('138790.00'), 'Tajikistan', 2015, Decimal('8.27'), Decimal('8.524063'), None),
#  ('Tajikistan', 'Central Asia', 'Central and Southern Asia', Decimal('138790.00'), 'Tajikistan', 2016, Decimal('6.99'), Decimal('8.725318'), Decimal('6.90')),
#  ('Tajikistan', 'Central Asia', 'Central and Southern Asia', Decimal('138790.00'), 'Tajikistan', 2017, Decimal('7.54'), Decimal('8.925525'), None),
#  ('Tajikistan', 'Central Asia', 'Central and Southern Asia', Decimal('138790.00'), 'Tajikistan', 2018, Decimal('7.77'), Decimal('9.128132'), None),
#  ('Tajikistan', 'Central Asia', 'Central and Southern Asia', Decimal('138790.00'), 'Tajikistan', 2019, Decimal('8.30'), Decimal('9.337003'), None),
#  ('Tajikistan', 'Central Asia', 'Central and Southern Asia', Decimal('138790.00'), 'Tajikistan', 2020, Decimal('8.13'), Decimal('9.543207'), None),
#  ('Thailand', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('510890.00'), 'Thailand', 2015, Decimal('401.30'), Decimal('70.294397'), Decimal('0.60')),
#  ('Thailand', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('510890.00'), 'Thailand', 2016, Decimal('413.37'), Decimal('70.607037'), Decimal('0.69')),
#  ('Thailand', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('510890.00'), 'Thailand', 2017, Decimal('456.36'), Decimal('70.898202'), Decimal('0.83')),
#  ('Thailand', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('510890.00'), 'Thailand', 2018, Decimal('506.75'), Decimal('71.127802'), Decimal('0.77')),
#  ('Thailand', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('510890.00'), 'Thailand', 2019, Decimal('544.08'), Decimal('71.307763'), Decimal('0.72')),
#  ('Thailand', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('510890.00'), 'Thailand', 2020, Decimal('499.68'), Decimal('71.475664'), Decimal('1.10')),
#  ('Timor-Leste', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('14870.00'), 'Timor-Leste', 2015, Decimal('1.59'), Decimal('1.205813'), None),
#  ('Timor-Leste', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('14870.00'), 'Timor-Leste', 2016, Decimal('1.65'), Decimal('1.224562'), Decimal('4.66')),
#  ('Timor-Leste', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('14870.00'), 'Timor-Leste', 2017, Decimal('1.60'), Decimal('1.243235'), None),
#  ('Timor-Leste', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('14870.00'), 'Timor-Leste', 2018, Decimal('1.56'), Decimal('1.261845'), None),
#  ('Timor-Leste', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('14870.00'), 'Timor-Leste', 2019, Decimal('2.03'), Decimal('1.280438'), None),
#  ('Timor-Leste', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('14870.00'), 'Timor-Leste', 2020, Decimal('2.16'), Decimal('1.299995'), None),
#  ('Togo', 'Western Africa', 'Sub-Saharan Africa', Decimal('54390.00'), 'Togo', 2015, Decimal('4.18'), Decimal('7.473229'), Decimal('2.20')),
#  ('Togo', 'Western Africa', 'Sub-Saharan Africa', Decimal('54390.00'), 'Togo', 2016, Decimal('6.03'), Decimal('7.661354'), None),
#  ('Togo', 'Western Africa', 'Sub-Saharan Africa', Decimal('54390.00'), 'Togo', 2017, Decimal('6.40'), Decimal('7.852795'), Decimal('3.74')),
#  ('Togo', 'Western Africa', 'Sub-Saharan Africa', Decimal('54390.00'), 'Togo', 2018, Decimal('7.11'), Decimal('8.046679'), None),
#  ('Togo', 'Western Africa', 'Sub-Saharan Africa', Decimal('54390.00'), 'Togo', 2019, Decimal('7.22'), Decimal('8.243094'), None),
#  ('Togo', 'Western Africa', 'Sub-Saharan Africa', Decimal('54390.00'), 'Togo', 2020, Decimal('7.57'), Decimal('8.442580'), None),
#  ('Tokelau', 'Polynesia', 'Oceania', None, 'Tokelau', 2015, None, None, None),
#  ('Tokelau', 'Polynesia', 'Oceania', None, 'Tokelau', 2016, None, None, None),
#  ('Tokelau', 'Polynesia', 'Oceania', None, 'Tokelau', 2017, None, None, None),
#  ('Tokelau', 'Polynesia', 'Oceania', None, 'Tokelau', 2018, None, None, None),
#  ('Tokelau', 'Polynesia', 'Oceania', None, 'Tokelau', 2019, None, None, None),
#  ('Tokelau', 'Polynesia', 'Oceania', None, 'Tokelau', 2020, None, None, None),
#  ('Tonga', 'Polynesia', 'Oceania', Decimal('720.00'), 'Tonga', 2015, Decimal('0.44'), Decimal('0.106122'), None),
#  ('Tonga', 'Polynesia', 'Oceania', Decimal('720.00'), 'Tonga', 2016, Decimal('0.42'), Decimal('0.105707'), None),
#  ('Tonga', 'Polynesia', 'Oceania', Decimal('720.00'), 'Tonga', 2017, Decimal('0.46'), Decimal('0.105415'), None),
#  ('Tonga', 'Polynesia', 'Oceania', Decimal('720.00'), 'Tonga', 2018, Decimal('0.49'), Decimal('0.105150'), Decimal('2.25')),
#  ('Tonga', 'Polynesia', 'Oceania', Decimal('720.00'), 'Tonga', 2019, Decimal('0.51'), Decimal('0.104951'), None),
#  ('Tonga', 'Polynesia', 'Oceania', Decimal('720.00'), 'Tonga', 2020, Decimal('0.48'), Decimal('0.105254'), None),
#  ('Trinidad and Tobago', 'Caribbean', 'Latin America and the Caribbean', Decimal('5130.00'), 'Trinidad and Tobago', 2015, Decimal('26.85'), Decimal('1.460177'), Decimal('2.43')),
#  ('Trinidad and Tobago', 'Caribbean', 'Latin America and the Caribbean', Decimal('5130.00'), 'Trinidad and Tobago', 2016, Decimal('23.50'), Decimal('1.469330'), Decimal('3.21')),
#  ('Trinidad and Tobago', 'Caribbean', 'Latin America and the Caribbean', Decimal('5130.00'), 'Trinidad and Tobago', 2017, Decimal('23.80'), Decimal('1.478607'), None),
#  ('Trinidad and Tobago', 'Caribbean', 'Latin America and the Caribbean', Decimal('5130.00'), 'Trinidad and Tobago', 2018, Decimal('24.32'), Decimal('1.504709'), None),
#  ('Trinidad and Tobago', 'Caribbean', 'Latin America and the Caribbean', Decimal('5130.00'), 'Trinidad and Tobago', 2019, Decimal('23.85'), Decimal('1.519955'), Decimal('3.52')),
#  ('Trinidad and Tobago', 'Caribbean', 'Latin America and the Caribbean', Decimal('5130.00'), 'Trinidad and Tobago', 2020, Decimal('21.06'), Decimal('1.518147'), Decimal('4.21')),
#  ('Tunisia', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('155360.00'), 'Tunisia', 2015, Decimal('45.78'), Decimal('11.557779'), Decimal('15.16')),
#  ('Tunisia', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('155360.00'), 'Tunisia', 2016, Decimal('44.36'), Decimal('11.685667'), Decimal('15.56')),
#  ('Tunisia', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('155360.00'), 'Tunisia', 2017, Decimal('42.16'), Decimal('11.811443'), Decimal('15.33')),
#  ('Tunisia', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('155360.00'), 'Tunisia', 2018, Decimal('42.69'), Decimal('11.933041'), Decimal('15.46')),
#  ('Tunisia', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('155360.00'), 'Tunisia', 2019, Decimal('41.91'), Decimal('12.049314'), Decimal('15.13')),
#  ('Tunisia', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('155360.00'), 'Tunisia', 2020, Decimal('42.54'), Decimal('12.161723'), None),
#  ('Türkiye', 'Western Asia', 'Northern Africa and Western Asia', None, 'Türkiye', 2015, None, None, None),
#  ('Türkiye', 'Western Asia', 'Northern Africa and Western Asia', None, 'Türkiye', 2016, None, None, None),
#  ('Türkiye', 'Western Asia', 'Northern Africa and Western Asia', None, 'Türkiye', 2017, None, None, None),
#  ('Türkiye', 'Western Asia', 'Northern Africa and Western Asia', None, 'Türkiye', 2018, None, None, None),
#  ('Türkiye', 'Western Asia', 'Northern Africa and Western Asia', None, 'Türkiye', 2019, None, None, None),
#  ('Türkiye', 'Western Asia', 'Northern Africa and Western Asia', None, 'Türkiye', 2020, None, None, None),
#  ('Turkmenistan', 'Central Asia', 'Central and Southern Asia', Decimal('469930.00'), 'Turkmenistan', 2015, Decimal('35.80'), Decimal('5.766431'), None),
#  ('Turkmenistan', 'Central Asia', 'Central and Southern Asia', Decimal('469930.00'), 'Turkmenistan', 2016, Decimal('36.17'), Decimal('5.868561'), None),
#  ('Turkmenistan', 'Central Asia', 'Central and Southern Asia', Decimal('469930.00'), 'Turkmenistan', 2017, Decimal('37.93'), Decimal('5.968383'), None),
#  ('Turkmenistan', 'Central Asia', 'Central and Southern Asia', Decimal('469930.00'), 'Turkmenistan', 2018, Decimal('40.77'), Decimal('6.065066'), None),
#  ('Turkmenistan', 'Central Asia', 'Central and Southern Asia', Decimal('469930.00'), 'Turkmenistan', 2019, Decimal('45.23'), Decimal('6.158420'), None),
#  ('Turkmenistan', 'Central Asia', 'Central and Southern Asia', Decimal('469930.00'), 'Turkmenistan', 2020, None, Decimal('6.250438'), None),
#  ('Turks and Caicos Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('950.00'), 'Turks and Caicos Islands', 2015, Decimal('0.94'), Decimal('0.036538'), None),
#  ('Turks and Caicos Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('950.00'), 'Turks and Caicos Islands', 2016, Decimal('1.03'), Decimal('0.038246'), None),
#  ('Turks and Caicos Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('950.00'), 'Turks and Caicos Islands', 2017, Decimal('1.02'), Decimal('0.039844'), None),
#  ('Turks and Caicos Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('950.00'), 'Turks and Caicos Islands', 2018, Decimal('1.11'), Decimal('0.041487'), None),
#  ('Tuvalu', 'Polynesia', 'Oceania', Decimal('30.00'), 'Tuvalu', 2015, Decimal('0.04'), Decimal('0.010877'), None),
#  ('Tuvalu', 'Polynesia', 'Oceania', Decimal('30.00'), 'Tuvalu', 2016, Decimal('0.04'), Decimal('0.010852'), Decimal('8.49')),
#  ('Tuvalu', 'Polynesia', 'Oceania', Decimal('30.00'), 'Tuvalu', 2017, Decimal('0.05'), Decimal('0.010828'), Decimal('26.55')),
#  ('Tuvalu', 'Polynesia', 'Oceania', Decimal('30.00'), 'Tuvalu', 2018, Decimal('0.05'), Decimal('0.010865'), None),
#  ('Tuvalu', 'Polynesia', 'Oceania', Decimal('30.00'), 'Tuvalu', 2019, Decimal('0.05'), Decimal('0.010956'), None),
#  ('Tuvalu', 'Polynesia', 'Oceania', Decimal('30.00'), 'Tuvalu', 2020, Decimal('0.06'), Decimal('0.011069'), None),
#  ('Uganda', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('200520.00'), 'Uganda', 2015, Decimal('32.39'), Decimal('37.477356'), None),
#  ('Uganda', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('200520.00'), 'Uganda', 2016, Decimal('29.20'), Decimal('38.748299'), None),
#  ('Uganda', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('200520.00'), 'Uganda', 2017, Decimal('30.74'), Decimal('40.127085'), Decimal('3.64')),
#  ('Uganda', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('200520.00'), 'Uganda', 2018, Decimal('32.93'), Decimal('41.515395'), None),
#  ('Uganda', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('200520.00'), 'Uganda', 2019, Decimal('35.35'), Decimal('42.949080'), None),
#  ('Uganda', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('200520.00'), 'Uganda', 2020, Decimal('37.60'), Decimal('44.404611'), None),
#  ('United Arab Emirates', 'Western Asia', 'Northern Africa and Western Asia', Decimal('71020.00'), 'United Arab Emirates', 2015, Decimal('370.28'), Decimal('8.916899'), None),
#  ('United Arab Emirates', 'Western Asia', 'Northern Africa and Western Asia', Decimal('71020.00'), 'United Arab Emirates', 2016, Decimal('369.26'), Decimal('8.994263'), Decimal('1.64')),
#  ('United Arab Emirates', 'Western Asia', 'Northern Africa and Western Asia', Decimal('71020.00'), 'United Arab Emirates', 2017, Decimal('390.52'), Decimal('9.068296'), Decimal('2.46')),
#  ('United Arab Emirates', 'Western Asia', 'Northern Africa and Western Asia', Decimal('71020.00'), 'United Arab Emirates', 2018, Decimal('427.05'), Decimal('9.140169'), Decimal('2.24')),
#  ('United Arab Emirates', 'Western Asia', 'Northern Africa and Western Asia', Decimal('71020.00'), 'United Arab Emirates', 2019, Decimal('417.99'), Decimal('9.211657'), Decimal('2.33')),
#  ('United Arab Emirates', 'Western Asia', 'Northern Africa and Western Asia', Decimal('71020.00'), 'United Arab Emirates', 2020, Decimal('349.47'), Decimal('9.287289'), Decimal('4.29')),
#  ('United Republic of Tanzania', 'Eastern Africa', 'Sub-Saharan Africa', None, 'United Republic of Tanzania', 2015, None, None, None),
#  ('United Republic of Tanzania', 'Eastern Africa', 'Sub-Saharan Africa', None, 'United Republic of Tanzania', 2016, None, None, None),
#  ('United Republic of Tanzania', 'Eastern Africa', 'Sub-Saharan Africa', None, 'United Republic of Tanzania', 2017, None, None, None),
#  ('United Republic of Tanzania', 'Eastern Africa', 'Sub-Saharan Africa', None, 'United Republic of Tanzania', 2018, None, None, None),
#  ('United Republic of Tanzania', 'Eastern Africa', 'Sub-Saharan Africa', None, 'United Republic of Tanzania', 2019, None, None, None),
#  ('United Republic of Tanzania', 'Eastern Africa', 'Sub-Saharan Africa', None, 'United Republic of Tanzania', 2020, None, None, None),
#  ('United States of America', 'Northern America', 'Europe and Northern America', None, 'United States of America', 2015, None, None, None),
#  ('United States of America', 'Northern America', 'Europe and Northern America', None, 'United States of America', 2016, None, None, None),
#  ('United States of America', 'Northern America', 'Europe and Northern America', None, 'United States of America', 2017, None, None, None),
#  ('United States of America', 'Northern America', 'Europe and Northern America', None, 'United States of America', 2018, None, None, None),
#  ('United States of America', 'Northern America', 'Europe and Northern America', None, 'United States of America', 2019, None, None, None),
#  ('United States of America', 'Northern America', 'Europe and Northern America', None, 'United States of America', 2020, None, None, None),
#  ('United States Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', None, 'United States Virgin Islands', 2015, None, None, None),
#  ('United States Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', None, 'United States Virgin Islands', 2016, None, None, None),
#  ('United States Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', None, 'United States Virgin Islands', 2017, None, None, None),
#  ('United States Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', None, 'United States Virgin Islands', 2018, None, None, None),
#  ('United States Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', None, 'United States Virgin Islands', 2019, None, None, None),
#  ('United States Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', None, 'United States Virgin Islands', 2020, None, None, None),
#  ('Uruguay', 'South America', 'Latin America and the Caribbean', Decimal('175020.00'), 'Uruguay', 2015, Decimal('53.27'), Decimal('3.402818'), Decimal('7.49')),
#  ('Uruguay', 'South America', 'Latin America and the Caribbean', Decimal('175020.00'), 'Uruguay', 2016, Decimal('57.24'), Decimal('3.413766'), Decimal('7.84')),
#  ('Uruguay', 'South America', 'Latin America and the Caribbean', Decimal('175020.00'), 'Uruguay', 2017, Decimal('64.23'), Decimal('3.422200'), Decimal('7.89')),
#  ('Uruguay', 'South America', 'Latin America and the Caribbean', Decimal('175020.00'), 'Uruguay', 2018, Decimal('64.52'), Decimal('3.427042'), Decimal('8.34')),
#  ('Uruguay', 'South America', 'Latin America and the Caribbean', Decimal('175020.00'), 'Uruguay', 2019, Decimal('61.23'), Decimal('3.428409'), Decimal('8.73')),
#  ('Uruguay', 'South America', 'Latin America and the Caribbean', Decimal('175020.00'), 'Uruguay', 2020, Decimal('53.56'), Decimal('3.429086'), Decimal('10.33')),
#  ...]

# %% [markdown]
# ### 2. Second `LEFT JOIN`
#
# Combine the previously joined tables with the `Basic_Services` table, again based on the `Country_name` column.

# %%
# %%sql
#
# SELECT
# 	*
# FROM
# 	united_nations.Geographic_Location as g
# LEFT JOIN
# 	united_nations.Economic_Indicators as e
# 	ON g.Country_name = e.Country_name
# LEFT JOIN
# 	united_nations.Basic_Services as b
# 	ON b.Country_name = g.Country_name
# 	AND e.Time_period = b.Time_period
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.753499'), None, 'Afghanistan', 2015, Decimal('67.00'), Decimal('45.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.636207'), None, 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.643418'), Decimal('11.18'), 'Afghanistan', 2017, Decimal('72.33'), Decimal('49.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2018, Decimal('18.42'), Decimal('36.686784'), None, 'Afghanistan', 2018, Decimal('75.33'), Decimal('50.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2019, Decimal('18.90'), Decimal('37.769499'), None, 'Afghanistan', 2019, Decimal('78.00'), Decimal('52.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2020, Decimal('20.14'), Decimal('38.972230'), Decimal('11.71'), 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2015, Decimal('165.98'), Decimal('39.543154'), Decimal('11.21'), 'Algeria', 2015, Decimal('92.00'), Decimal('85.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2016, Decimal('160.03'), Decimal('40.339329'), Decimal('10.20'), 'Algeria', 2016, Decimal('93.00'), Decimal('85.33')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2017, Decimal('170.10'), Decimal('41.136546'), Decimal('12.00'), 'Algeria', 2017, Decimal('93.00'), Decimal('84.67')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2018, Decimal('174.91'), Decimal('41.927007'), None, 'Algeria', 2018, Decimal('93.00'), Decimal('84.67'))]

# %% [markdown]
# ### 3. Refine the second `LEFT JOIN`
#
# At first glance, the results of the above query might seem fine, but take a closer look at the `Time_periods`. We can see that they don't align as we would expect.
#
# Refine the second `LEFT JOIN` query by adding an additional condition based on the `Time_period` column.

# %%
# %%sql
# # Add your code here
# # Use LIMIT if you expect a large result set

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. First `LEFT JOIN`

# %%
# %%sql
#
# SELECT
# 	*
# FROM
# 	united_nations.Geographic_Location as geo
# LEFT JOIN
# 	united_nations.Economic_Indicators as econ
# 	ON geo.Country_name = econ.Country_name
# LIMIT 50;

# %% [markdown]
# With this LEFT JOIN, we will get all the records from the `Geographic_Location` table and only the matching records from the `Economic_Indicators` table. If there is no match, we will still get the data from the `Geographic_Location` table, and the columns from the `Economic_Indicators` table will be `NULL`.

# %% [markdown]
# ### 2. Second `LEFT JOIN`

# %%
# %%sql
#
# SELECT
# 	*
# FROM
# 	united_nations.Geographic_Location as geo
# LEFT JOIN
# 	united_nations.Economic_Indicators as econ
# 	ON geo.Country_name = econ.Country_name
# LEFT JOIN
# 	united_nations.Basic_Services as svc
# 	ON geo.Country_name = svc.Country_name
# LIMIT 20;

# %% [markdown]
# ### 3. Refine second `LEFT JOIN`

# %%
# %%sql
#
# SELECT
# 	*
# FROM
# 	united_nations.Geographic_Location as geo
# LEFT JOIN
# 	united_nations.Economic_Indicators as econ
# 	ON geo.Country_name = econ.Country_name
# LEFT JOIN
# 	united_nations.Basic_Services as svc
# 	ON geo.Country_name = svc.Country_name
# 	AND econ.Time_period = svc.Time_period
# LIMIT 20;

# %% [markdown]
# With the additional condition, we ensure that the `Time_periods` align correctly and we get the desired output.

# %% [markdown]
# ## Summary
#
# This notebook shows how Entity-Relationship Diagrams can help us understand database joins better. We specifically focused on the `LEFT JOIN` technique, which is widely used to combine tables. Additionally, we noticed the importance of picking the right joining strategy, as incorrect joins can lead to inaccurate results.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
